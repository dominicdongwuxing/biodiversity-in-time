# %%
# load pre-computed files
WIKIDIR = "../dataset/wikidata"
data = pd.read_csv(os.path.join(WIKIDIR, "full_parsed.csv"))[["id","taxon_name","taxon_rank","parent_taxon","species_name_value"]]
with open(os.path.join(WIKIDIR, "tree_flat.pkl"),"rb") as tree_f, open(os.path.join(WIKIDIR, "id_name_lookup.pkl"),"rb") as id_name_f, open(os.path.join(WIKIDIR, "id_rank_lookup.pkl"),"rb") as id_rank_f:
    tree, id_name_dict, id_rank_dict = pickle.load(tree_f), pickle.load(id_name_f), pickle.load(id_rank_f)
# Out:
# /home/dongwuxing/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (4,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import pandas as pd
import numpy as np
import os
import time
import pickle
import math
import collections
import json

DATADIR = "../dataset"
WIKI_DIR = DATADIR + "/wikidata"
PARSED_WIKI_DIR = WIKI_DIR + "/parsed"

def is_nan(value):
    '''
    check if a value is nan
    return boolean
    '''
    try:
        return math.isnan(float(value))
    except:
        return False
    

def build_tree_with_taxon_name (data, id_name_dict):
    '''
    no longer used.
    generate tree of life using the taxon names and parent names (not "Q..." code)
    from the fully combined parsed data 
    return dict
    '''
    tree_dict = {}
    for i in range(data.shape[0]):
        parent_code = data["parent_taxon"][i]
        # find the taxon name of the entry or the species_name_value of it
        name = data["taxon_name"][i]
        if name == None or is_nan(name):
            name = "species_name_value_" + data["species_name_value"][i]
        # only process entries with a certain parent node 
        if parent_code != None and not is_nan(parent_code):
            # retrieve taxon name of the parent taxon, if None then species_name_value
            parent_name = id_name_dict[parent_code]
                
            if parent_name not in tree_dict:
                tree_dict[parent_name] = [name]
            else:
                tree_dict[parent_name].append(name)
    return tree_dict

def build_tree (data):
    '''
    generate tree of life using the code names 
    from the fully combined parsed data 
    return dict, where key is each parent code and 
    values are their corresponding children codes
    '''
    tree_dict = {}
    for i in range(data.shape[0]):
        parent_code = data["parent_taxon"][i]
        name = data["id"][i]

        # only process entries with a certain parent node 
        if parent_code != None and not is_nan(parent_code):
            if parent_code not in tree_dict:
                tree_dict[parent_code] = [name]
            else:
                tree_dict[parent_code].append(name)
    
    for i in range(data.shape[0]):
        potential_leaf = data["id"][i]
        if potential_leaf not in tree_dict:
            tree_dict[potential_leaf] = []
    return tree_dict

# it will take 30 seconds on my computer
def build_parent_lookup(data):
    '''
    compared to build_parent_lookup_naive, a much quicker way to
    build a lookup dict to link parent_taxon code to a name. 
    Its keys are parent_taxon code ("Q....")
    and values are the corresponding taxon_name, if taxon_name is nan, then the 
    values are the corresponding species_name_value, if the parent_taxon code
    is not in the "id" attribute of the fully combined parsed data, then the
    corresponding values are just the original parent_taxon code
    return: dict
    '''
    def get_sorted_parents(data):
        '''
        sort all parent_taxon in the data,
        a helper function for build_parent_lookup
        return list
        '''
        parents = data["parent_taxon"].unique().tolist()
        ids = data["id"].unique().tolist()
        for parent in parents:
            if is_nan(parent):
                parents.remove(parent)
        parents = sorted(parents)
        return parents
    
    id_name_dict = {}
    data = data.sort_values(by=['id'],ignore_index=True)
    parents = get_sorted_parents(data)
    assert data["id"].tolist() == data["id"].unique().tolist()
    ids = data["id"].tolist()
    current_idx, previous_idx = 0,0
    start = time.time()
    while len(parents):
        # process the first parent in parent list
        parent = parents[0]
        # if the parent_taxon has not been found after looping the entire id list, 
        # then loop back to the previous idx and put the parent_taxon code itself as name
        if parent != ids[-1] and current_idx == len(ids)-1:
            current_idx = previous_idx 
            id_name_dict[parent] = parent
            parents.pop(0)
            
        # parent id matches an id on the id list
        elif parent == ids[current_idx]:
            name = data.loc[current_idx,"taxon_name"]
            if is_nan(name):
                # add a "species_name_" tag in front of species name, when taxon name is not available
                name = "species_name: " + data.loc[current_idx,"species_name_value"]
            id_name_dict[parent] = name
            parents.pop(0)
            current_idx += 1
            previous_idx = current_idx
            
        # parent id doesn't match 
        else:
            current_idx += 1
                 
    return id_name_dict


# it will take 2.5 hours on my computer
def build_parent_lookup_naive(data):
    '''
    a naive and slow way to perform the same function as build_parent_lookup
    no longer used
    '''
    id_name_dict = {}
    id_list = data["id"].tolist()
    i = 0
    for parent in data["parent_taxon"].unique():
        i += 1
        if i % 1000 == 0:
            time_taken = round(time.time() - start, 2)
            print(time_taken, " seconds, processing " + str(i))
        if not is_nan(parent):
            # if parent id can be found in id list then retrieve its taxon name or species_name_value
            try:
                idx = id_list.index(parent)
                name = data.loc[idx,"taxon_name"]
                if is_nan(name):
                    # add a "species_name_" tag in front of species name, when taxon name is not available
                    name = "species_name: " + data.loc[idx,"species_name_value"]
                id_name_dict[parent] = name
            # if parent id cannot be found in id list then its id = its name
            except ValueError:
                id_name_dict[parent] = parent
    return id_name_dict

def get_path_to_root(tree,bottom_node):
    '''
    very slow.
    for an item in the tree, recursively search for its parent
    until finding the root, or detecting a cycle
    It does not detect multiple parent case (only follow path for one parent)
    return a list of ancestors for a child, the list ends in its root
    or a node in a cycle. In the cycle case, the list ends in the word "cycle"
    '''
    def add_parent_to_path(node):
        for key in tree.keys():
            if node in tree[key]:
                parent_list.append(key)
                if parent_list.count(parent_list[-1]) > 1:
                    parent_list.append("cycle!")
                else:
                    add_parent_to_path(key)
                # do not consider alternative path when multi-parents occur
                break
                
    parent_list = [bottom_node]
    add_parent_to_path(bottom_node)
    return parent_list

def get_node_parent(tree):
    '''
    very slow.
    get parent of all nodes in the tree
    return dict, where keys are nodes,
    values are their corresponding parent(s)
    '''
    count = 0
    node_parent = {}
    for node in tree.keys():
        count += 1
        if count % 100 == 0:
            print(count)
        parent = []
        for parent_candidate in tree.keys():
            if node in tree[parent_candidate]:
                parent.append(parent_candidate)
                
        node_parent[node] = parent
    return node_parent

def get_repetitive_taxon_name(data):
    '''
    for all repetitive taxon names, show how many counts there are in the data
    return dict, where key is repetitve taxon name, value is corresponding count
    '''
    count = collections.Counter(data[data["taxon_name"].notna()]["taxon_name"])
    for key, value in list(count.items()):
        if value == 1:
            del count[key]
    return dict(count)

def get_id_to_name_lookup(data):
    ''' 
    Build a look up dictionary of id codes to taxon names for all entries.
    If taxon_name is nan, then the species_name_value is used.
    return: dict, where keys are id codes and values are corresponding taxon_name,
    or species_name_value
    '''
    
    id_name_dict = {}
    ids, taxon_names, species_name_values = data["id"],data["taxon_name"],data["species_name_value"]
    for i in range(len(data)):
        id_code, name = ids[i], taxon_names[i]
        if is_nan(name):
            # use_species_name_value when taxon name is not available
            name = species_name_values[i]
        id_name_dict[id_code] = name

    return id_name_dict

def get_id_to_rank_lookup(data):
    ''' 
    Build a look up dictionary of id codes to taxon ranks for all entries.
    return: dict, where keys are id codes and values are corresponding taxon_rank,
    or None
    '''
    
    id_rank_dict = {}
    ids, taxon_ranks = data["id"],data["taxon_rank"]
    for i in range(len(data)):
        id_code, rank = ids[i], taxon_ranks[i]
        if is_nan(rank):
            rank = "NA"
        id_rank_dict[id_code] = rank

    return id_rank_dict


def get_missing_parents(id_name_dict,data):
    '''
    Look for missing parents, which are parents whose id cannot be found in the data
    return: list of id code of the missing parents.
    '''
    missing_parents = []
    for parent in data[data["parent_taxon"].notna()]["parent_taxon"].unique().tolist():
        if parent not in id_name_dict:
            missing_parents.append(parent)
    return missing_parents

def build_tree_from_root(root_id, tree, id_name, id_rank):
    try:
        name = id_name[root_id]
    except KeyError:
        name = ""
        
    try:
        rank = id_rank[root_id]
    except KeyError:
        rank = ""
    
    rooted_tree = {"name":name,"rank":rank, "id": root_id, "children":[build_tree_from_root(child_id,tree,id_name,id_rank) for child_id in tree[root_id]]}
    
    if rooted_tree["children"] == []:
        del rooted_tree["children"]
    else:
        # merge nodes or leaves that are siblings but has identical taxon names
        repeated_names = [item for item, count in collections.Counter([child["name"] for child in rooted_tree["children"]]).items() if count > 1]
        new_children_list = [child for child in rooted_tree["children"] if child["name"] not in repeated_names]
        for rep in repeated_names:
            replacement = {"name":rep,"rank":"", "id": "","children":[]}
            for child in rooted_tree["children"]:
                if child["name"] == rep:
                    if replacement["id"]:
                        replacement["id"] += "_" + child["id"]
                    else:
                        replacement["id"] = child["id"]
                    if replacement["rank"]:
                        replacement["rank"] += "_" + child["rank"]
                    else:
                        replacement["rank"] = child["rank"]
                    
                    if "children" in child.keys():
                        try:
                            replacement["children"] += child["children"]
                        except KeyError:
                            replacement["children"] = child["children"]
            new_children_list.append(replacement)

        rooted_tree["children"] = new_children_list
    return rooted_tree

# %%
# combine all parsed JSON files into one file (maybe this work has already been done and saved as wikidata_records.csv)
data = pd.DataFrame()
for file in os.listdir(PARSED_WIKI_DIR):
    temp_data = pd.read_json(os.path.join(PARSED_WIKI_DIR,file))
    data = pd.concat([data,temp_data],ignore_index=True)

# break species_name into two attributes: species_name_language and species_name_value
species_name_language, species_name_value = \
[data["species_name"][i]["language"] for i in range(data.shape[0])],\
[data["species_name"][i]["value"] for i in range(data.shape[0])]

data["species_name_value"], data["species_name_language"] = species_name_value,species_name_language
data = data.drop(columns="species_name")
data.to_csv(PARSED_WIKI_DIR + "/full_parsed.csv", index= False)

# %%
'''
when an item has no taxon name but has a parent taxon, use its species_name_value as its name.
"Neonymphon sp." and "Wainuia" are two species_name_value that equals the taxon names of other
items
'''
all_taxon_names = data["taxon_name"].unique()
species_values = data[data["taxon_name"].isna() & data["parent_taxon"].notna()]["species_name_value"].tolist()

print("species_name_value that is also present in taxon_names: ")
for species_value in species_values:
    if species_value in all_taxon_names:
        print(species_value)

'''
In cases where species_name_value names are used, these names are also not all unique. 
There are two "Bedotia spec." that use species_name_value

'''
print("not unique species_name_value: ")
species_count = collections.Counter(species_values)
for c in species_count.keys():
    if species_count[c] != 1:
        print(c + ": " + str(species_count[c]))

# %%
'''
The two Neonymphon sp. species can be merged
And the Wainuia is the parent of the second Wainuia
'''
data[
    (data["species_name_value"] == "Neonymphon sp.")
    | (data["species_name_value"] == "Wainuia")
    | (data["taxon_name"] == "Neonymphon sp.") 
    | (data["taxon_name"] == "Wainuia")
]
# Out:
#                 id      taxon_name taxon_rank parent_taxon species_name_value
# 1435832  Q63708474  Neonymphon sp.      Q7432    Q11845937     Neonymphon sp.
# 1488753   Q1905950             NaN      Q7432    Q11845937     Neonymphon sp.
# 1527131   Q3076049         Wainuia     Q34740     Q3075210            Wainuia
# 2881841   Q7960198             NaN      Q7432     Q3076049            Wainuia

# %%
'''
These two species can be merged
'''
data[data["species_name_value"] == "Bedotia spec."]
# Out:
#                id taxon_name taxon_rank parent_taxon species_name_value
# 973595   Q4879358        NaN      Q7432      Q141320      Bedotia spec.
# 2860033  Q4879370        NaN      Q7432      Q141320      Bedotia spec.

# %%
# create a dict whose keys are parent_taxon code and value is the corresponding name (parent taxon code, or taxon name, or species_name_value)
#id_name_dict = build_parent_lookup(data)
#parent_id_to_name_dict_file = open(os.path.join(WIKI_DIR,"parent_id_to_name_dict.pkl"), "wb")
#pickle.dump(id_name_dict, parent_id_to_name_dict_file)
#parent_id_to_name_dict_file.close()

# create a dict whose keys are all id codes and values are its corresponding taxon name, if null then species_name_value
id_name_dict = get_id_to_name_lookup(data)
id_name_dict_file = open(os.path.join(WIKI_DIR,"id_name_lookup.pkl"), "wb")
pickle.dump(id_name_dict, id_name_dict_file)
id_name_dict_file.close()

# create a dict whose keys are all id codes and values are its corresponding taxon rank, if null then None
id_rank_dict = get_id_to_rank_lookup(data)
id_rank_dict_file = open(os.path.join(WIKI_DIR,"id_rank_lookup.pkl"), "wb")
pickle.dump(id_rank_dict, id_rank_dict_file)
id_rank_dict_file.close()
'''
There are some parent_taxon that is not in the id list 
There are also three parent_taxon who don't have a taxon_name, therefore, its species_name_value is used instead:
They are:

(Q21350434) species_name: Carabus subdiv. Procrustimorphi
(Q21350423) species_name: Carabus div. Multistriati
(Q21350410) species_name: Carabus div. Carabogenici
'''

# %%
'''
these are the parents that are not present in the list of ids
which means they have no record in the wikidata



separate_roots = []
for code, taxon in id_name_dict.items():
    if code == taxon:
        separate_roots.append(code)
'''
missing_parents = get_missing_parents(id_name_dict, data)
missing_parents
# Out:
# ['Q15869465',
#  'Q99442800',
#  'Q17319474',
#  'Q4150646',
#  'Q235536',
#  'Q27110262',
#  'Q99521037',
#  'Q15341165',
#  'Q13411080',
#  'Q27973466',
#  'Q5226073',
#  'Q96381504',
#  'Q72288',
#  'Q845214',
#  'Q102318370',
#  'Q105134179',
#  'Q105134195',
#  'Q105452043',
#  'Q934008',
#  'Q102043669',
#  'Q19409463',
#  'Q17285269',
#  'Q102047357',
#  'Q56453547',
#  'Q100582257',
#  'Q105134193',
#  'Q21367139',
#  'Q84986611',
#  'Q105130613',
#  'Q14458220',
#  'Q99424267']

# %%
'''
There are 9482 taxon_name repeating for twice,
322 taxon_name repeating 3 times,
25 taxon_name repeating for 4 times,
6 taxon_name repeating for 5 times,
1 taxon_name repeating for 7 times
'''
repetitive_taxon_name = get_repetitive_taxon_name(data)

collections.Counter(repetitive_taxon_name.values())

# %%
'''
Since data has repetitive taxon names, which leads to cycles in the tree
and incorrectly merged nodes, we use unique id code to build tree instead
of taxon names
'''
tree = build_tree(data)

tree_file = open(os.path.join(WIKI_DIR,"tree_flat.pkl"), "wb")
pickle.dump(tree, tree_file)
tree_file.close()

# %%
'''
for each group of siblings, check if there are repetitions in the taxon names
'''
repetitive_taxon_names = {}
for node_code, children_code in tree.items():
    try:
        children_names = [id_name_dict[child] for child in children_code]
        if len(children_names) != len(set(children_names)):
            repetitive_children = {}
            for i in range(len(children_names)):
                if children_names.count(children_names[i]) > 1:
                    repetition_name = children_names[i]
                    if repetition_name not in repetitive_children:
                        repetitive_children[repetition_name] = [children_code[i]]
                    else:
                        repetitive_children[repetition_name].append(children_code[i])
            repetitive_taxon_names[node_code] = repetitive_children                         
            print(node_code, "has children with same taxon names: ", repetitive_children, "\n")
    except:
        continue
# Out:
# Q10771886 has children with same taxon names:  {'Roegneria shandongensis': ['Q94445016', 'Q94445021']}
#
# Q157634 has children with same taxon names:  {'Clematis ‘Star of India’': ['Q2978844', 'Q83638443'], 'Clematis lineariloba': ['Q93342747', 'Q93342713']}
#
# Q34687 has children with same taxon names:  {'Rosa ‘Ave Maria’': ['Q2873382', 'Q96278591'], 'Rosa ‘Broadway’': ['Q24192323', 'Q83690929'], 'Rosa ‘Clementine’': ['Q30893497', 'Q83666700'], 'Rosa ‘Cabana’': ['Q83646992', 'Q83738140'], 'Rosa ‘Violetta’': ['Q83670269', 'Q83690940'], 'Rosa ‘Bordeaux’': ['Q83671863', 'Q83690957'], 'Rosa ‘Golden Border’': ['Q83690731', 'Q83690886'], 'Rosa ‘Matilda’': ['Q83690853', 'Q83668974'], 'Rosa ‘Mambo’': ['Q83690866', 'Q16626382'], 'Rosa ‘Indian Summer’': ['Q83690882', 'Q83675226'], 'Rosa ‘Kathleen’': ['Q83690936', 'Q83667956'], 'Rosa ‘Bianca’': ['Q96278546', 'Q83667443'], 'Rosa ‘Elfe’': ['Q4048459', 'Q83690802'], 'Rosa ‘Silva’': ['Q83647122', 'Q83738965'], 'Rosa ‘Parks’ Yellow Tea-scented China’': ['Q83661592', 'Q96634306'], 'Rosa ‘Coralie’': ['Q83666967', 'Q83690951'], 'Rosa ‘Le Cid’': ['Q83668633', 'Q83690975'], 'Rosa ‘Louis Philippe’': ['Q83668693', 'Q83690944'], 'Rosa ‘Esmeralda’': ['Q83690870', 'Q83664534'], 'Rosa ‘Bajazzo’': ['Q83690880', 'Q96278570'], 'Rosa ‘Bengali’': ['Q83690916', 'Q83666228'], 'Rosa ‘Colette’': ['Q83690969', 'Q83666825'], 'Rosa ‘Elle’': ['Q83690971', 'Q83667192'], 'Rosa balsamica': ['Q16918451', 'Q85056282'], 'Rosa ‘Garden Party’': ['Q1494069', 'Q83690925'], 'Rosa ‘Prestige de Lyon’': ['Q64030591', 'Q83669672'], 'Rosa ‘Aloha’': ['Q83646930', 'Q83690946'], 'Rosa ‘Abracadabra’': ['Q83666004', 'Q83690927'], 'Rosa ‘Benita’': ['Q83666231', 'Q83690919'], 'Rosa ‘Mandarin’': ['Q83668994', 'Q83690905', 'Q83690793'], 'Rosa ‘Evening Star’': ['Q83690831', 'Q66664373'], 'Rosa ‘Kardinal’': ['Q83690885', 'Q83667922'], 'Rosa ‘Mardi Gras’': ['Q83690962', 'Q66425358'], 'Rosa ‘Queen of Hearts’': ['Q83738548', 'Q83647228'], 'Rosa ‘Bossa Nova’': ['Q83660410', 'Q96242839'], 'Rosa ‘Charisma’': ['Q83666853', 'Q83690959'], 'Rosa ‘Inka’': ['Q83668315', 'Q83690933'], 'Rosa ‘Mikado’': ['Q83673219', 'Q83690907'], 'Rosa ‘Florentina’': ['Q83690931', 'Q83667366'], 'Rosa ‘Avenir’': ['Q83690964', 'Q83666158'], 'Rosa ‘Fortuna’': ['Q83690973', 'Q83667373'], 'Rosa ‘Bolero’': ['Q83666483', 'Q96242882'], 'Rosa ‘Madame Scipion Cochet’': ['Q83672542', 'Q100741542'], 'Rosa ‘Avon’': ['Q83690890', 'Q83665998'], 'Rosa ‘Kleopatra’': ['Q83690899', 'Q83690898'], 'Rosa ‘Carmen’': ['Q83690922', 'Q83666614', 'Q83690948'], 'Rosa ‘Frénésie’': ['Q83690980', 'Q83674210'], 'Rosa ‘Canary Bird’': ['Q2936174', 'Q83690836'], 'Rosa Polyantha Group': ['Q10636372', 'Q2102731'], 'Rosa ‘Moonlight’': ['Q83665464', 'Q83690953'], 'Rosa ‘Applause’': ['Q83690795', 'Q83690938'], 'Rosa ‘Paprika’': ['Q83690901', 'Q16472509'], 'Rosa ‘Daphne’': ['Q83690914', 'Q83667107'], 'Rosa ‘Viola’': ['Q83671046', 'Q83690966'], 'Rosa ‘Morgenrot’': ['Q83690977', 'Q23928565']}
#
# Q158974 has children with same taxon names:  {'Primula fragilis': ['Q94391055', 'Q94390993']}
#
# Q310492 has children with same taxon names:  {'Ziziphus zizyphus': ['Q96321364', 'Q242963']}
#
# Q7216874 has children with same taxon names:  {'Veronica sect. Scutellatae': ['Q93394728', 'Q93394696']}
#
# Q2815989 has children with same taxon names:  {'Odontochilus elongatus': ['Q92126432', 'Q92126486'], 'Odontochilus fimbriatus': ['Q92126529', 'Q92126578']}
#
# Q159568 has children with same taxon names:  {'Corydalis sect. Oreocapnos': ['Q94310048', 'Q93345368']}
#
# Q9265342 has children with same taxon names:  {'Galeobdolon endtmannii': ['Q94360843', 'Q93357628']}
#
# Q3314456 has children with same taxon names:  {'Spermacoce hondurensis': ['Q93392082', 'Q93392099']}
#
# Q1354085 has children with same taxon names:  {'Ovatus': ['Q104915861', 'Q10613583'], 'Tuberolachnus': ['Q104249399', 'Q10705909']}
#
# Q145794 has children with same taxon names:  {'Sphenosciadium': ['Q104977995', 'Q15967232']}
#
# Q158991 has children with same taxon names:  {'Opuntia gaumeri': ['Q91449923', 'Q91449897'], 'Opuntia bonnieae': ['Q94335911', 'Q94335876']}
#
# Q42292 has children with same taxon names:  {'Acer ‘Pacific Sunset’': ['Q18470226', 'Q9576340']}
#
# Q133733 has children with same taxon names:  {'Cattleya novyi': ['Q95573831', 'Q95984579']}
#
# Q228283 has children with same taxon names:  {'Felis mexicana': ['Q64827871', 'Q64827865', 'Q64827858']}
#
# Q142252 has children with same taxon names:  {'Hechtia gayi': ['Q94523793', 'Q94523808']}
#
# Q146418 has children with same taxon names:  {'Racinaea pulchella': ['Q93060131', 'Q92238839'], 'Racinaea riocreuxii': ['Q92313814', 'Q81746500']}
#
# Q25400 has children with same taxon names:  {'Leptocarpha': ['Q6527974', 'Q104991996']}
#
# Q311221 has children with same taxon names:  {'Druryia': ['Q56421533', 'Q16981423']}
#
# Q155874 has children with same taxon names:  {'Agave tuberosa': ['Q38490984', 'Q64402156']}
#
# Q14619186 has children with same taxon names:  {'Servaisia': ['Q50548901', 'Q21440071']}
#
# Q7048131 has children with same taxon names:  {'Angensteinia': ['Q21218567', 'Q21440807']}
#
# Q5028551 has children with same taxon names:  {'Campsicnemus mirabilis': ['Q21361628', 'Q21955198'], 'Campsicnemus hardyi': ['Q14533103', 'Q21361623']}
#
# Q162920 has children with same taxon names:  {'Erodium olympicum': ['Q94515680', 'Q94515706']}
#
# Q2161497 has children with same taxon names:  {'Pouteria glabra': ['Q94442363', 'Q94442399'], 'Pouteria nitida': ['Q94442466', 'Q94442432']}
#
# Q12004 has children with same taxon names:  {'Quercus obconica': ['Q94393223', 'Q94393200'], 'Quercus shangxiensis': ['Q94393910', 'Q94393948']}
#
# Q1210189 has children with same taxon names:  {'Sarcocaulon lavrani': ['Q94445373', 'Q94445401']}
#
# Q45669 has children with same taxon names:  {'Eucalyptus variegata': ['Q64831576', 'Q65938392']}
#
# Q765930 has children with same taxon names:  {'Clusia rosea': ['Q98842784', 'Q5775234']}
#
# Q160107 has children with same taxon names:  {'Delphinium sinoamabile': ['Q93424588', 'Q93424618']}
#
# Q146095 has children with same taxon names:  {'Viola sect. Mirabiles': ['Q94410637', 'Q94410670'], 'Viola sect. Estolonosae': ['Q94410333', 'Q94410359']}
#
# Q157069 has children with same taxon names:  {'Campanula allionii': ['Q21155554', 'Q79399407']}
#
# Q1514169 has children with same taxon names:  {'Helvella retirugis': ['Q105055824', 'Q105055823']}
#
# Q904250 has children with same taxon names:  {'Psychotria carapichea': ['Q93442152', 'Q93442173']}
#
# Q133754 has children with same taxon names:  {'Oncidium subcruciforme': ['Q94335057', 'Q94335022']}
#
# Q29979 has children with same taxon names:  {'Pleurothallis trinitensis': ['Q93385187', 'Q93385136'], 'Pleurothallis aondae': ['Q93384591', 'Q93384624'], 'Pleurothallis hilariana': ['Q93384880', 'Q93384924'], 'Pleurothallis fritzii': ['Q93384780', 'Q93384831']}
#
# Q8353041 has children with same taxon names:  {'Cyrtochilum pastorellii': ['Q94413510', 'Q94413539']}
#
# Q160110 has children with same taxon names:  {'Mimosa pedunculata': ['Q67449167', 'Q67453964', 'Q67456305']}
#
# Q148633 has children with same taxon names:  {'Galium gracilens': ['Q96939296', 'Q15247342']}
#
# Q133778 has children with same taxon names:  {'Dendrobium mitriferum': ['Q93349385', 'Q93349432']}
#
# Q2720003 has children with same taxon names:  {'Stelis modesta': ['Q20965932', 'Q2118603']}
#
# Q15952699 has children with same taxon names:  {'Stenostomum sect. Neolaugeria': ['Q94562225', 'Q94562280']}
#
# Q3906027 has children with same taxon names:  {'Fernandezia robusta': ['Q94517467', 'Q94517445']}
#
# Q2716243 has children with same taxon names:  {'Dalea occidentalis': ['Q94350795', 'Q94350859']}
#
# Q2283735 has children with same taxon names:  {'Stichorkis gibbosa': ['Q92578649', 'Q92578611']}
#
# Q7616507 has children with same taxon names:  {'Stigmatosema longibracteatum': ['Q93392290', 'Q93392306'], 'Stigmatosema pedicellatum': ['Q94563086', 'Q94563039']}
#
# Q1305617 has children with same taxon names:  {'Anomogyna': ['Q21439018', 'Q21445909']}
#
# Q13424318 has children with same taxon names:  {'Cotesia lasallei': ['Q96373037', 'Q96372803']}
#
# Q2470787 has children with same taxon names:  {'Digitapamea': ['Q21220328', 'Q21440101'], 'Cernauncus': ['Q21230813', 'Q21440092'], 'Alexapamea': ['Q21439272', 'Q21216179']}
#
# Q133728 has children with same taxon names:  {'Epidendrum ×gransabanense': ['Q93305850', 'Q15470602']}
#
# Q1756340 has children with same taxon names:  {'Lonchocarpus fluvialis': ['Q94433857', 'Q94433877']}
#
# Q59798 has children with same taxon names:  {'Ficus trichopoda': ['Q98591523', 'Q13035470']}
# Q158501 has children with same taxon names:  {'Carex nebrascensis': ['Q5039106', 'Q65210266']}
#
# Q163988 has children with same taxon names:  {'Neottia subg. Listera': ['Q94537199', 'Q94537168'], 'Neottia grandiflora': ['Q94537379', 'Q94537413'], 'Neottia australis': ['Q94537238', 'Q94537260']}
#
# Q161173 has children with same taxon names:  {'Ipomoea ×sloteri': ['Q104485194', 'Q6065278']}
#
# Q141475 has children with same taxon names:  {'Orostachys ramosissima': ['Q94377165', 'Q94377212']}
#
# Q3283496 has children with same taxon names:  {'Pinalia connata': ['Q92667992', 'Q92668044']}
#
# Q157017 has children with same taxon names:  {'Magnolia soulangeana': ['Q104864635', 'Q104864638']}
#
# Q164454 has children with same taxon names:  {'Calliandra paganuccii': ['Q92627549', 'Q92627606']}
#
# Q15980308 has children with same taxon names:  {'Calonema bicalliatum': ['Q93416703', 'Q93416659'], 'Calonema flaccidum': ['Q93417844', 'Q93417813'], 'Calonema filamentosum': ['Q93417508', 'Q93417594'], 'Calonema filiferum': ['Q93417633', 'Q93417668'], 'Calonema caesareum': ['Q93416853', 'Q93416810'], 'Calonema denticulatum': ['Q93417226', 'Q93417127'], 'Calonema dorrienii': ['Q93417257', 'Q93417283'], 'Calonema sigmoideum': ['Q93418334', 'Q93418302']}
#
# Q7512441 has children with same taxon names:  {'Sigmatostalix occultans': ['Q93395143', 'Q93395174'], 'Sigmatostalix ×luerorum': ['Q94400061', 'Q94400098']}
#
# Q2333069 has children with same taxon names:  {'Paspalum ramianum': ['Q94338100', 'Q94338073']}
#
# Q1853773 has children with same taxon names:  {'Gigantochloa baliana': ['Q15516698', 'Q99337200']}
#
# Q2194043 has children with same taxon names:  {'Pseudoxytenanthera ritchiei': ['Q94442834', 'Q94442835']}
#
# Q132239 has children with same taxon names:  {'Citrullus citrullus': ['Q103843134', 'Q103843157']}
#
# Q146555 has children with same taxon names:  {'Solanum ferox': ['Q105079251', 'Q105079406', 'Q105079510', 'Q4208374']}
#
# Q13174500 has children with same taxon names:  {'Cerasus ilicifolius': ['Q95931026', 'Q95930451']}
#
# Q3775608 has children with same taxon names:  {'Senegalia langsdorffii': ['Q93068567', 'Q93068615'], 'Senegalia piauhiensis': ['Q93069070', 'Q93069116'], 'Senegalia kallunkiae': ['Q93068372', 'Q93068322'], 'Senegalia santosii': ['Q93069276', 'Q93069330']}
#
# Q9002132 has children with same taxon names:  {'Harpalyce lanata': ['Q94362627', 'Q94362674']}
#
# Q311305 has children with same taxon names:  {'Sesbania sect. Daubentoniopsis': ['Q94558717', 'Q94558660']}
#
# Q134496 has children with same taxon names:  {'Trichosanthes integrifolia': ['Q103850986', 'Q17431407']}
#
# Q157411 has children with same taxon names:  {'Colchicum agrippinum': ['Q105036143', 'Q105036145'], 'Colchicum byzantinum': ['Q105036153', 'Q105036152']}
#
# Q2701631 has children with same taxon names:  {'Stylosanthes maracajuensis': ['Q93317356', 'Q93317371']}
#
# Q209596 has children with same taxon names:  {'Senecio hebdingii': ['Q94399741', 'Q94399796']}
#
# Q3003873 has children with same taxon names:  {'Trixis pruskii': ['Q93394310', 'Q93394290']}
#
# Q1411311 has children with same taxon names:  {'Vernonia ornata': ['Q104703897', 'Q15567883']}
#
# Q2245746 has children with same taxon names:  {'Wedelia rudis': ['Q94450541', 'Q94450537']}
#
# Q15941264 has children with same taxon names:  {'Oberna anatolica': ['Q94436039', 'Q94436068'], 'Oberna aeoniopsis': ['Q94436013', 'Q94435995']}
#
# Q116209 has children with same taxon names:  {'Silene maximowicziana': ['Q94560173', 'Q94560230']}
#
# Q4157859 has children with same taxon names:  {'Dendranthema nankingense': ['Q94316245', 'Q94316280']}
#
# Q30024 has children with same taxon names:  {'Taraxacum rupestre': ['Q94405288', 'Q94405343'], 'Taraxacum pratense': ['Q94404933', 'Q94404880']}
#
# Q146617 has children with same taxon names:  {'Achillea stricta': ['Q11748523', 'Q38699594']}
#
# Q1761521 has children with same taxon names:  {'Ericameria depressa': ['Q94514806', 'Q94514828']}
#
# Q1446121 has children with same taxon names:  {'Gomphrena sericea': ['Q69356840', 'Q17246104']}
#
# Q158011 has children with same taxon names:  {'Buddleja ‘Purple Haze’': ['Q4984390', 'Q4984368']}
#
# Q6312757 has children with same taxon names:  {'Jungia sect. Dumerilia': ['Q94529354', 'Q94529390']}
#
# Q671075 has children with same taxon names:  {'Pulicaria longifolia': ['Q94342304', 'Q94342327']}
#
# Q17168646 has children with same taxon names:  {'Nephrodium motleyanum': ['Q95951393', 'Q95951446']}
#
# Q1354632 has children with same taxon names:  {'Peperomia obtusifolia': ['Q98593816', 'Q7166271']}
#
# Q19744 has children with same taxon names:  {'Boletus pachypus': ['Q12021261', 'Q105049962'], 'Boletus australis': ['Q12200196', 'Q105049873'], 'Boletus distortus': ['Q54363368', 'Q105049903'], 'Boletus conchifer': ['Q54370167', 'Q105049897'], 'Boletus abietinus': ['Q54370745', 'Q105049853'], 'Boletus obscurecoccineus': ['Q59428136', 'Q105049958'], 'Boletus fibula': ['Q59474731', 'Q105049914'], 'Boletus balloui': ['Q59565373', 'Q105049877'], 'Boletus magnificus': ['Q97143876', 'Q105049944'], 'Boletus ananas': ['Q105049867', 'Q54360303'], 'Boletus bovinus': ['Q105049881', 'Q12200192'], 'Boletus cookei': ['Q105049896', 'Q10432393'], 'Boletus megalosporus': ['Q105049950', 'Q10432401'], 'Boletus curtisii': ['Q4939346', 'Q105049899'], 'Boletus pinicola': ['Q10432408', 'Q105049966'], 'Boletus badius': ['Q28654165', 'Q96636867'], 'Boletus porphyrosporus': ['Q46823872', 'Q105049971'], 'Boletus gilvus': ['Q59548477', 'Q105049924'], 'Boletus luridiformis': ['Q95951659', 'Q105049941'], 'Boletus cuticularis': ['Q105049900', 'Q54359231'], 'Boletus ovinus': ['Q105049961', 'Q59419388'], 'Boletus strobilaceus': ['Q105049997', 'Q59578406'], 'Boletus terrestris': ['Q105050007', 'Q54366044'], 'Boletus fomentarius': ['Q21872028', 'Q105049917'], 'Boletus fragrans': ['Q2257400', 'Q105049918'], 'Boletus flavus': ['Q10432396', 'Q105049915'], 'Boletus albidus': ['Q12200219', 'Q105049863'], 'Boletus biennis': ['Q12200220', 'Q105049880'], 'Boletus luteus': ['Q14469099', 'Q105049943'], 'Boletus austrofelleus': ['Q59590465', 'Q105049874'], 'Boletus piperatus': ['Q64785595', 'Q105049967'], 'Boletus cyanescens': ['Q96635754', 'Q105049901'], 'Boletus applanatus': ['Q105049871', 'Q59511576'], 'Boletus confluens': ['Q105049895', 'Q96635152'], 'Boletus igniarius': ['Q105049932', 'Q21872030'], 'Boletus leonis': ['Q105049938', 'Q41712401'], 'Boletus mollis': ['Q105049952', 'Q54366649'], 'Boletus sanguineus': ['Q105049985', 'Q105049986'], 'Boletus chrysenteron': ['Q41475394', 'Q105049892'], 'Boletus luridus': ['Q41597775', 'Q105049942'], 'Boletus indecisus': ['Q98073316', 'Q105049933'], 'Boletus tabacinus': ['Q105050003', 'Q59578573'], 'Boletus brownii': ['Q105049883', 'Q59505137'], 'Boletus vaillantii': ['Q105050012', 'Q54370688'], 'Boletus erythropus': ['Q728666', 'Q105049909'], 'Boletus glabellus': ['Q15637186', 'Q105049925'], 'Boletus varius': ['Q96939529', 'Q105050014'], 'Boletus felleus': ['Q105049912', 'Q59578431'], 'Boletus giganteus': ['Q105049923', 'Q54366243'], 'Boletus hepaticus': ['Q105049929', 'Q54364263'], 'Boletus subtomentosus': ['Q105050000', 'Q21872037'], 'Boletus xylophilus': ['Q105050019', 'Q97151129'], 'Boletus nigerrimus': ['Q59564887', 'Q105049956'], 'Boletus calopus': ['Q1137151', 'Q105049887'], 'Boletus leptospermi': ['Q105049939', 'Q2909347']}
#
# Q310475 has children with same taxon names:  {'Septoria pelargonii': ['Q105066837', 'Q105066838']}
#
# Q3966739 has children with same taxon names:  {'Spilocaea pyracanthae': ['Q15634563', 'Q105067077']}
#
# Q25420 has children with same taxon names:  {'Luciolinae': ['Q104865983', 'Q3265858']}
#
# Q10420904 has children with same taxon names:  {'Astraeus hygrometricus': ['Q980655', 'Q105049668']}
#
# Q1498027 has children with same taxon names:  {'Gymnopilus allantopus': ['Q105055489', 'Q5624710'], 'Gymnopilus penetrans': ['Q105055499', 'Q10497177'], 'Gymnopilus crociphyllus': ['Q105055496', 'Q5224390'], 'Gymnopilus austrosapineus': ['Q105055493', 'Q5624728'], 'Gymnopilus anomalus': ['Q105055491', 'Q10763387'], 'Gymnopilus austropicreus': ['Q105055492', 'Q5624727'], 'Gymnopilus purpuratus': ['Q105055498', 'Q5624954']}
#
# Q573661 has children with same taxon names:  {'Tricholoma saponaceum': ['Q1473080', 'Q105068293'], 'Tricholoma caligatum': ['Q3998692', 'Q105068267'], 'Tricholoma terreum': ['Q105068298', 'Q27266']}
#
# Q1492335 has children with same taxon names:  {'Tylopilus porphyrosporus': ['Q46823579', 'Q105068476'], 'Tylopilus eximius': ['Q105068472', 'Q27439577'], 'Tylopilus ferrugineus': ['Q105068474', 'Q15636172'], 'Tylopilus austrofelleus': ['Q26325901', 'Q105068469'], 'Tylopilus tabacinus': ['Q105068481', 'Q4051901'], 'Tylopilus indecisus': ['Q15637191', 'Q105068475'], 'Tylopilus rubrobrunneus': ['Q15637374', 'Q105068478'], 'Tylopilus felleus': ['Q633503', 'Q105068473']}
#
# Q850667 has children with same taxon names:  {'Psilocybe murcida': ['Q105066225', 'Q105066224'], 'Psilocybe subcubensis': ['Q7255944', 'Q105066237'], 'Psilocybe foenisecii': ['Q105066216', 'Q105066215'], 'Psilocybe echinata': ['Q105066213', 'Q105066212'], 'Psilocybe longinqua': ['Q104519274', 'Q105066222'], 'Psilocybe cubensis': ['Q690450', 'Q105066209'], 'Psilocybe cyanescens': ['Q105066211', 'Q882592'], 'Psilocybe inquilina': ['Q105066218', 'Q844481'], 'Psilocybe semilanceata': ['Q105066232', 'Q503359']}
#
# Q368612 has children with same taxon names:  {'Clitocybe ditopa': ['Q10455187', 'Q105050965'], 'Clitocybe dealbata': ['Q105050963', 'Q1402263'], 'Clitocybe proxima': ['Q105050994', 'Q59531598'], 'Clitocybe pruinosa': ['Q105050996', 'Q10567629'], 'Clitocybe candicans': ['Q2979406', 'Q105050956'], 'Clitocybe infundibuliformis': ['Q105050976', 'Q10455205'], 'Clitocybe nebularis': ['Q105050986', 'Q757125'], 'Clitocybe phyllophila': ['Q883698', 'Q105050993'], 'Clitocybe brumalis': ['Q3915572', 'Q105050951'], 'Clitocybe paraditopa': ['Q10455216', 'Q105050990'], 'Clitocybe gibba': ['Q46795429', 'Q105050972'], 'Clitocybe elegans': ['Q62071515', 'Q105050966'], 'Clitocybe hydrogramma': ['Q105050975', 'Q10455204'], 'Clitocybe rivulosa': ['Q105050997', 'Q2720076'], 'Clitocybe cerussata': ['Q105050957', 'Q11262781']}
#
# Q13910202 has children with same taxon names:  {'Epermeniola': ['Q21439147', 'Q21224180']}
#
# Q180597 has children with same taxon names:  {'Fucus aculeatus': ['Q28913967', 'Q67216957']}
# Q775899 has children with same taxon names:  {'Dibrachia': ['Q21219947', 'Q51823874']}
#
# Q19360237 has children with same taxon names:  {'Polycoccum crespoae': ['Q21302728', 'Q105065248'], 'Polycoccum jamesii': ['Q105065249', 'Q21302684']}
#
# Q3919240 has children with same taxon names:  {'Lecidea arthonioides': ['Q87818246', 'Q87818397']}
#
# Q1933387 has children with same taxon names:  {'Conocybe candida': ['Q105051390', 'Q10458472'], 'Conocybe crispa': ['Q105051392', 'Q10458474'], 'Conocybe tenera': ['Q1641496', 'Q105051402'], 'Conocybe togularis': ['Q10458541', 'Q105051403'], 'Conocybe rickenii': ['Q105051399', 'Q5162125'], 'Conocybe blattaria': ['Q105051389', 'Q10458468'], 'Conocybe rickeniana': ['Q105051398', 'Q10458523'], 'Conocybe rugosa': ['Q105051400', 'Q10458525'], 'Conocybe apala': ['Q1632206', 'Q105051388']}
#
# Q5118293 has children with same taxon names:  {'Agylla virilis': ['Q7913066', 'Q99695551']}
#
# Q602790 has children with same taxon names:  {'Arctata': ['Q21221074', 'Q21438954'], 'Coleta': ['Q10749489', 'Q21438957']}
#
# Q3457990 has children with same taxon names:  {'Haliclona': ['Q61480432', 'Q104853628']}
#
# Q2306024 has children with same taxon names:  {'Monolepta daklaka': ['Q104368540', 'Q46791524']}
#
# Q7830470 has children with same taxon names:  {'Ceratocheilus': ['Q21230664', 'Q21438501'], 'Eutoxorhina': ['Q21226654', 'Q21438502']}
#
# Q940917 has children with same taxon names:  {'Deranchylaeus': ['Q22103008', 'Q21219322']}
#
# Q459180 has children with same taxon names:  {'Amphipyrinae': ['Q104863889', 'Q14552207']}
#
# Q213938 has children with same taxon names:  {'Amanita basibulbosa': ['Q18477732', 'Q105049119'], 'Amanita conicoverrucosa': ['Q18477866', 'Q105049149'], 'Amanita bisporigera': ['Q4033858', 'Q105049123'], 'Amanita murinaster': ['Q19702666', 'Q105049202'], 'Amanita nummularia': ['Q59484346', 'Q105049208'], 'Amanita variabilis': ['Q61962633', 'Q105049264'], 'Amanita ananiceps': ['Q105049107', 'Q16748362'], 'Amanita austroviridis': ['Q105049117', 'Q18477721'], 'Amanita eliae': ['Q105049156', 'Q1673664'], 'Amanita fuscosquamosa': ['Q105049168', 'Q18477979'], 'Amanita ochraceobulbosa': ['Q105049209', 'Q18478101'], 'Amanita strobiliformis': ['Q105049253', 'Q1445543'], 'Amanita subvaginata': ['Q4739886', 'Q105049260'], 'Amanita marmorata': ['Q49433592', 'Q105049200'], 'Amanita alboverrucosa': ['Q105049103', 'Q18477609'], 'Amanita albovolvata': ['Q105049104', 'Q18477623'], 'Amanita armeniaca': ['Q105049112', 'Q18477683'], 'Amanita cinerascens': ['Q105049130', 'Q19702657'], 'Amanita citrina': ['Q105049132', 'Q935729'], 'Amanita gracilenta': ['Q105049172', 'Q18477999'], 'Amanita ochrophylla': ['Q105049210', 'Q15632553'], 'Amanita pallidochracea': ['Q105049218', 'Q18478131'], 'Amanita pantherina': ['Q105049221', 'Q45547'], 'Amanita egreginus': ['Q18477922', 'Q105049155'], 'Amanita roseolamellata': ['Q18478254', 'Q105049233'], 'Amanita strobilaceoides': ['Q18478311', 'Q105049254'], 'Amanita fulva': ['Q301792', 'Q105049166'], 'Amanita vaginata': ['Q913459', 'Q105049263'], 'Amanita albosquamosa': ['Q18477594', 'Q105049102'], 'Amanita allostraminea': ['Q18477634', 'Q105049105'], 'Amanita aspera': ['Q55650793', 'Q105049113'], 'Amanita chlorophylla': ['Q105049129', 'Q18477782'], 'Amanita farinacea': ['Q105049161', 'Q49602891'], 'Amanita flavella': ['Q105049163', 'Q4739871'], 'Amanita muscaria': ['Q105049205', 'Q131227'], 'Amanita phalloides': ['Q105049224', 'Q188643'], 'Amanita murina': ['Q49425348', 'Q105049201'], 'Amanita pyramidiferina': ['Q105049230', 'Q19702670'], 'Amanita virosa': ['Q472817', 'Q105049269'], 'Amanita persicina': ['Q49633239', 'Q105049223'], 'Amanita basiorubra': ['Q105049120', 'Q18477745'], 'Amanita lesueurii': ['Q105049192', 'Q19595859'], 'Amanita ovoidea': ['Q105049215', 'Q1281074'], 'Amanita ponderosa': ['Q105049225', 'Q8197035'], 'Amanita ochrophylloides': ['Q15632556', 'Q105049211'], 'Amanita luteofusca': ['Q105049195', 'Q18478053'], 'Amanita luteivolvata': ['Q19702664', 'Q105049194'], 'Amanita gemmata': ['Q1063083', 'Q105049169'], 'Amanita fuscobrunnea': ['Q19702662', 'Q105049167'], 'Amanita rubescens': ['Q105049234', 'Q623485'], 'Amanita sordidobubalina': ['Q18478262', 'Q105049235'], 'Amanita spissa': ['Q105049237', 'Q1323749']}
#
# Q7415384 has children with same taxon names:  {'Bostrichus': ['Q104383819', 'Q4948287']}
#
# Q4116306 has children with same taxon names:  {'Petrosia': ['Q56611500', 'Q105027570']}
#
# Q156569 has children with same taxon names:  {'Strumpfia': ['Q15964045', 'Q104389146']}
#
# Q596145 has children with same taxon names:  {'Hygrophorus': ['Q96994318', 'Q622043']}
#
# Q11687 has children with same taxon names:  {'Antillattus': ['Q95485573', 'Q567027']}
#
# Q37204 has children with same taxon names:  {'Apini': ['Q104415099', 'Q2858308']}
#
# Q373530 has children with same taxon names:  {'Blepharidina': ['Q21353665', 'Q84384924']}
#
# Q2311247 has children with same taxon names:  {'Cangoderces globosa': ['Q50839813', 'Q68852496']}
#
# Q156584 has children with same taxon names:  {'Neoshirakia': ['Q104847962', 'Q15711488'], 'Anisophyllum': ['Q98013306', 'Q98013748'], 'Hippomanoideae': ['Q88392239', 'Q88391715']}
#
# Q13872246 has children with same taxon names:  {'Austrobaileya': ['Q15712331', 'Q104247091']}
#
# Q2705558 has children with same taxon names:  {'Psathyrella candolleana': ['Q105066104', 'Q772657'], 'Psathyrella trepida': ['Q10641648', 'Q105066118']}
#
# Q1210088 has children with same taxon names:  {'Otiorhynchus titarenkoi': ['Q29032542', 'Q88381416'], 'Otiorhynchus zierisi': ['Q88381385', 'Q29032545']}
#
# Q342881 has children with same taxon names:  {'Capotrichis': ['Q21440182', 'Q21229249']}
#
# Q1366572 has children with same taxon names:  {'Auropolia': ['Q21439254', 'Q21222802'], 'Chalapolia': ['Q21231104', 'Q21439275']}
#
# Q645804 has children with same taxon names:  {'Balachowskyna': ['Q21223978', 'Q21441074'], 'Cytheritis': ['Q21218280', 'Q21441071']}
#
# Q2099 has children with same taxon names:  {'Entoloma bloxamii': ['Q1956186', 'Q105053624'], 'Entoloma austroprunicolor': ['Q5380586', 'Q105053621'], 'Entoloma sordidulum': ['Q63436149', 'Q5231737'], 'Entoloma crassipes': ['Q63454460', 'Q63441737'], 'Entoloma aromaticum': ['Q105053559', 'Q10484545'], 'Entoloma nitidum': ['Q105053679', 'Q239680'], 'Entoloma sericellum': ['Q105053707', 'Q4038106'], 'Entoloma virescens': ['Q1952827', 'Q105053774'], 'Entoloma rhodopolium': ['Q2422232', 'Q105053698'], 'Entoloma panniculus': ['Q10484710', 'Q105053683'], 'Entoloma asprellum': ['Q10681839', 'Q105053619'], 'Entoloma flavum': ['Q63440192', 'Q63440149'], 'Entoloma byssisedum': ['Q105053627', 'Q4532089'], 'Entoloma formosum': ['Q105053648', 'Q10484623'], 'Entoloma hochstetteri': ['Q2602685', 'Q105053659'], 'Entoloma conferendum': ['Q3915400', 'Q105053637'], 'Entoloma strictum': ['Q10484774', 'Q105053771'], 'Entoloma asprelloides': ['Q10484546', 'Q105053618'], 'Entoloma aethiops': ['Q105053553', 'Q10484536'], 'Entoloma depluens': ['Q105053643', 'Q10431192'], 'Entoloma mammosum': ['Q105053670', 'Q5229600'], 'Entoloma sericeum': ['Q10667808', 'Q105053767'], 'Entoloma parsonsiae': ['Q105053685', 'Q10484714'], 'Entoloma rodwayi': ['Q105053699', 'Q5380594'], 'Entoloma rufocarneum': ['Q105053703', 'Q10484759'], 'Entoloma pluteoides': ['Q63441706', 'Q63453741'], 'Entoloma procerum': ['Q105053693', 'Q10484736'], 'Entoloma euchroum': ['Q105053644', 'Q1949938']}
#
# Q156551 has children with same taxon names:  {'Kitaibelia': ['Q104388698', 'Q104388699']}
#
# Q205295 has children with same taxon names:  {'Moala': ['Q14884620', 'Q19943805']}
#
# Q146030 has children with same taxon names:  {'Ruta': ['Q104096097', 'Q165250', 'Q104096099']}
#
# Q156192 has children with same taxon names:  {'Rehmannia': ['Q104249409', 'Q104249401', 'Q104249404', 'Q3313262']}
#
# Q26568 has children with same taxon names:  {'Neatostema': ['Q104389932', 'Q973820']}
#
# Q975872 has children with same taxon names:  {'Cassiope': ['Q574564', 'Q104247022'], 'Chamaedaphne': ['Q104247023', 'Q3502448']}
#
# Q3542771 has children with same taxon names:  {'Waltonia': ['Q15947099', 'Q21442001']}
#
# Q7618284 has children with same taxon names:  {'Cyrtacanthacridinae': ['Q899837', 'Q104915743'], 'Locusta': ['Q15122569', 'Q15878784']}
#
# Q2361375 has children with same taxon names:  {'Ustilago maydis': ['Q1430040', 'Q105068766'], 'Ustilago polytocae': ['Q105068782', 'Q105068781'], 'Ustilago trichophora': ['Q105068844', 'Q7216069'], 'Ustilago heironymi': ['Q105068749', 'Q105068750']}
#
# Q599518 has children with same taxon names:  {'Mentzelia': ['Q104385583', 'Q142498']}
#
# Q44120 has children with same taxon names:  {'Prunus domestica ‘Bluefre’': ['Q15987447', 'Q15987338']}
#
# Q2537809 has children with same taxon names:  {'Ascophyllum': ['Q16034614', 'Q104252549']}
#
# Q155802 has children with same taxon names:  {'Platycodon': ['Q104386794', 'Q104386790']}
#
# Q155941 has children with same taxon names:  {'Ixia': ['Q134748', 'Q85147225']}
# Q305162 has children with same taxon names:  {'Puccinia cymbopogonis': ['Q105066251', 'Q1449695'], 'Puccinia pelargonii-zonalis': ['Q10646270', 'Q105066256'], 'Puccinia xanthii': ['Q288667', 'Q105066260'], 'Puccinia kenmorensis': ['Q105066252', 'Q1478613'], 'Puccinia unica': ['Q105066259', 'Q1232996'], 'Puccinia calthae': ['Q105066250', 'Q1446218']}
#
# Q1754819 has children with same taxon names:  {'Paraleirides': ['Q50742230', 'Q56022295'], 'Cumeres': ['Q56005944', 'Q4036769'], 'Leiromorpha': ['Q4042748', 'Q56022289'], 'Bradytulus': ['Q56005941', 'Q4035376'], 'Parapercosia': ['Q56022296', 'Q50742245'], 'Amathitis': ['Q4033872', 'Q56005935'], 'Armatoleirides': ['Q4034380', 'Q56005938'], 'Harpaloamara': ['Q4040427', 'Q56022283'], 'Hyalamara': ['Q4040846', 'Q56022286'], 'Microleirus': ['Q4044212', 'Q56022292'], 'Leuris': ['Q56022291', 'Q4042822'], 'Paracelia': ['Q56022294', 'Q16528102'], 'Zabroscelis': ['Q50742297', 'Q56033111'], 'Amarocelia': ['Q56005934', 'Q4033871'], 'Leiramara': ['Q56022288', 'Q4042744'], 'Xanthamara': ['Q50742274', 'Q56033109'], 'Euderocycla': ['Q56022282', 'Q4038253'], 'Leiocnemis': ['Q56022287', 'Q4042738'], 'Leironotus': ['Q4042749', 'Q56022290'], 'Bradytodema': ['Q56005940', 'Q4035374']}
#
# Q7386 has children with same taxon names:  {'Aenictinae': ['Q105031065', 'Q9585014']}
#
# Q25497 has children with same taxon names:  {'Gazellospira': ['Q30672126', 'Q41153757']}
#
# Q161239 has children with same taxon names:  {'Sarcotoxicum': ['Q21293618', 'Q104852288']}
#
# Q371101 has children with same taxon names:  {'Morchella conica': ['Q105059168', 'Q1327882'], 'Morchella elata': ['Q105059171', 'Q627991']}
#
# Q131291 has children with same taxon names:  {'Lachnanthes': ['Q104915455', 'Q16880304']}
#
# Q1124575 has children with same taxon names:  {'Mycena sanguinolenta': ['Q785648', 'Q105059340'], 'Mycena aetites': ['Q3912823', 'Q105059211'], 'Mycena rorida': ['Q3915548', 'Q105059338'], 'Mycena acutata': ['Q105059209', 'Q105059210'], 'Mycena juncicola': ['Q105059302', 'Q10590951'], 'Mycena stylobates': ['Q6946911', 'Q105059343'], 'Mycena galericulata': ['Q1467364', 'Q105059291'], 'Mycena algeriensis': ['Q10546662', 'Q105059212'], 'Mycena epipterygia': ['Q105059226', 'Q1183020'], 'Mycena nargan': ['Q105059318', 'Q6946897'], 'Mycena lenta': ['Q97777166', 'Q105059305'], 'Mycena leptocephala': ['Q105059306', 'Q2565841'], 'Mycena cystidiosa': ['Q105059224', 'Q10590942'], 'Mycena rhaeborrhiza': ['Q105059334', 'Q105059335'], 'Mycena subcapillaris': ['Q105059345', 'Q105059346'], 'Mycena rimosacuta': ['Q105059336', 'Q105059337']}
#
# Q144144 has children with same taxon names:  {'Platanistida': ['Q18362265', 'Q21446454']}
#
# Q843104 has children with same taxon names:  {'Hemileucinae': ['Q104945684', 'Q1110630']}
#
# Q158717 has children with same taxon names:  {'Polyommatinae': ['Q104899714', 'Q460892']}
#
# Q532358 has children with same taxon names:  {'Chelodina oblonga': ['Q2697599', 'Q94998519']}
#
# Q683918 has children with same taxon names:  {'Marsupenaeus': ['Q3295077', 'Q104993756']}
#
# Q159372 has children with same taxon names:  {'Mimulus parviflorus': ['Q59262682', 'Q77853615']}
#
# Q311294 has children with same taxon names:  {'Phytophthora citrophthora': ['Q3901761', 'Q105064898'], 'Phytophthora erythroseptica': ['Q3010754', 'Q105064902'], 'Phytophthora multivora': ['Q105064910', 'Q3382067'], 'Phytophthora cinnamomi': ['Q2711566', 'Q105064897'], 'Phytophthora hibernalis': ['Q7189820', 'Q105064907'], 'Phytophthora fluvialis': ['Q105064903', 'Q105064905'], 'Phytophthora nicotianae': ['Q3018847', 'Q105064911'], 'Phytophthora parasitica': ['Q20686122', 'Q105064913']}
#
# Q1878350 has children with same taxon names:  {'Myristica malaccensis': ['Q17140635', 'Q99439709']}
#
# Q1136229 has children with same taxon names:  {'Ruvettus': ['Q14292607', 'Q104914333']}
#
# Q310441 has children with same taxon names:  {'Rebutia polypetala': ['Q93388790', 'Q94443858', 'Q93388768'], 'Rebutia haefneriana': ['Q94443421', 'Q93388301', 'Q93388336'], 'Rebutia yuncharasensis': ['Q94444151', 'Q93389134', 'Q93389112'], 'Rebutia major': ['Q93388467', 'Q94443516', 'Q93388457'], 'Rebutia nazarenoensis': ['Q93388512', 'Q93388499'], 'Rebutia parvula': ['Q93388675', 'Q94443797', 'Q93388644'], 'Rebutia violaceostaminata': ['Q93389091', 'Q94444111', 'Q93389058'], 'Rebutia applanata': ['Q94342749', 'Q94443144'], 'Rebutia tafnaensis': ['Q94444049', 'Q93389035', 'Q93389012'], 'Rebutia pelzliana': ['Q93388706', 'Q93388730', 'Q94443829'], 'Rebutia knizei': ['Q93388361', 'Q93388417', 'Q94443454'], 'Rebutia crassa': ['Q94342840', 'Q94443300']}
#
# Q1427328 has children with same taxon names:  {'Osmunda multifida': ['Q95939218', 'Q95939238']}
#
# Q131260 has children with same taxon names:  {'Candida glabrata': ['Q139137', 'Q105050232'], 'Candida tropicalis': ['Q105050239', 'Q143138']}
#
# Q150302 has children with same taxon names:  {'Trichostomum': ['Q66662498', 'Q1669740']}
#
# Q17387029 has children with same taxon names:  {'Hexagonia durissima': ['Q105055972', 'Q105055973'], 'Hexagonia bicolor': ['Q105055966', 'Q105055967']}
#
# Q131321 has children with same taxon names:  {'Paepalanthus': ['Q98399700', 'Q2539207']}
#
# Q1196275 has children with same taxon names:  {'Sparganium minimum': ['Q59262718', 'Q77846587']}
#
# Q4797622 has children with same taxon names:  {'Arthonia anjutii': ['Q21239361', 'Q105049498'], 'Arthonia subconveniens': ['Q21242230', 'Q105049501'], 'Arthonia intexta': ['Q10418599', 'Q105049499'], 'Arthonia ceracea': ['Q21239742', 'Q87933734'], 'Arthonia sytnikii': ['Q21242419', 'Q105049502']}
#
# Q310738 has children with same taxon names:  {'Cladonia diversa': ['Q104641175', 'Q3678876']}
#
# Q6947118 has children with same taxon names:  {'Mycocalicium subtile': ['Q105059376', 'Q10591083']}
#
# Q290423 has children with same taxon names:  {'Lecanora leptoplaca': ['Q61804212', 'Q61804192']}
#
# Q7095657 has children with same taxon names:  {'Opegrapha ectolechiacearum': ['Q105059930', 'Q21298251'], 'Opegrapha epiporina': ['Q105059931', 'Q21298211'], 'Opegrapha phylloporinae': ['Q105059933', 'Q21297405']}
#
# Q10559097 has children with same taxon names:  {'Leptorhaphis haematommatum': ['Q105057842', 'Q21275884']}
#
# Q1335970 has children with same taxon names:  {'Lycoperdon epidendrum': ['Q21976225', 'Q105058239'], 'Lycoperdon aestivale': ['Q59428359', 'Q105058152'], 'Lycoperdon gunnii': ['Q59436630', 'Q105058243'], 'Lycoperdon pyriforme': ['Q105058264', 'Q865798'], 'Lycoperdon reticulatum': ['Q105058267', 'Q105058268'], 'Lycoperdon polymorphum': ['Q10571325', 'Q105058258'], 'Lycoperdon fragile': ['Q105058234', 'Q105058233'], 'Lycoperdon stellatum': ['Q105058274', 'Q21976228'], 'Lycoperdon substellatum': ['Q105058277', 'Q105058276'], 'Lycoperdon tasmanicum': ['Q105058278', 'Q105058279'], 'Lycoperdon cyathiforme': ['Q59454343', 'Q105058236'], 'Lycoperdon cepiforme': ['Q105058161', 'Q105058162'], 'Lycoperdon pusillum': ['Q105058263', 'Q62521067'], 'Lycoperdon rugosum': ['Q105058271', 'Q59491577'], 'Lycoperdon natalense': ['Q105058249', 'Q105058251'], 'Lycoperdon utriforme': ['Q105058282', 'Q378497'], 'Lycoperdon bovista': ['Q105058157', 'Q21976216'], 'Lycoperdon polyrhizum': ['Q105058259', 'Q105058260'], 'Lycoperdon giganteum': ['Q59538106', 'Q105058241'], 'Lycoperdon aurantium': ['Q105058155', 'Q21976215'], 'Lycoperdon nitidum': ['Q105058252', 'Q105058253'], 'Lycoperdon perlatum': ['Q105058256', 'Q545130'], 'Lycoperdon glabrescens': ['Q105058242', 'Q10571320']}
#
# Q148794 has children with same taxon names:  {'Brachistus stramoniifolius': ['Q15547806', 'Q896597']}
#
# Q132419 has children with same taxon names:  {'Shorea chinensis': ['Q98592821', 'Q38825999']}
#
# Q269195 has children with same taxon names:  {'Plesiosauroidea': ['Q61882056', 'Q1619550']}
#
# Q753860 has children with same taxon names:  {'Phlebotominae': ['Q1416438', 'Q105026037']}
#
# Q1945822 has children with same taxon names:  {'Gibbonthophagus': ['Q21440729', 'Q19599189'], 'Colobonthophagus': ['Q20667926', 'Q21440722'], 'Onthophagiellus': ['Q19599149', 'Q21441660'], 'Onthophagus': ['Q18121680', 'Q21441597']}
#
# Q1068611 has children with same taxon names:  {'Ihlea': ['Q104375102', 'Q4915180']}
#
# Q10413373 has children with same taxon names:  {'Anthracoidea caryophylleae': ['Q7217033', 'Q105049356'], 'Anthracoidea heterospora': ['Q10413384', 'Q105049358']}
#
# Q60075 has children with same taxon names:  {'Cerithium chantrei': ['Q69968041', 'Q69968220']}
#
# Q5956531 has children with same taxon names:  {'Hymenogaster fulvus': ['Q59521376', 'Q105056548'], 'Hymenogaster levisporus': ['Q105056553', 'Q105056554'], 'Hymenogaster albellus': ['Q59503968', 'Q105056540']}
#
# Q6812546 has children with same taxon names:  {'Meliola emmenospermatus': ['Q105058766', 'Q105058767'], 'Meliola prostantherae': ['Q105058843', 'Q105058846'], 'Meliola dysoxylicola': ['Q105058764', 'Q105058765']}
#
# Q35047 has children with same taxon names:  {'Ctenopharyngodon': ['Q104936679', 'Q2478978']}
#
# Q132658 has children with same taxon names:  {'Retzia': ['Q18334775', 'Q104388957']}
#
# Q158487 has children with same taxon names:  {'Samyda': ['Q7413179', 'Q66558300']}
#
# Q5104090 has children with same taxon names:  {'Choiromyces aboriginus': ['Q105050468', 'Q105050469']}
#
# Q2620120 has children with same taxon names:  {'Gyroporus castaneus': ['Q1165913', 'Q105055531'], 'Gyroporus naranjus': ['Q105055539', 'Q105055538'], 'Gyroporus occidentalis': ['Q105055540', 'Q105055541'], 'Gyroporus robinsonii': ['Q105055543', 'Q105055542']}
#
# Q10676241 has children with same taxon names:  {'Sporisorium destruens': ['Q105067106', 'Q6741556']}
#
# Q14949949 has children with same taxon names:  {'Tolyposporium anthistiriae': ['Q105067919', 'Q105067918']}
#
# Q206627 has children with same taxon names:  {'Tremella mesenterica': ['Q105068133', 'Q19733']}
#
# Q5235905 has children with same taxon names:  {'Plectania melastoma': ['Q105064949', 'Q10519246']}
#
# Q149953 has children with same taxon names:  {'Gymnomitrioideae': ['Q104859236', 'Q104859234']}
#
# Q748899 has children with same taxon names:  {'Lactarius subdulcis': ['Q1724711', 'Q105057321'], 'Lactarius turpis': ['Q105057324', 'Q23637'], 'Lactarius torminosus': ['Q105057323', 'Q865540'], 'Lactarius tabidus': ['Q1427410', 'Q105057322']}
#
# Q664594 has children with same taxon names:  {'Lithothamnion corallioides': ['Q104991232', 'Q10319090']}
#
# Q292034 has children with same taxon names:  {'Duttus': ['Q21439222', 'Q21222209'], 'Arquagrilus': ['Q21221545', 'Q29167712'], 'Austragrilus': ['Q21222841', 'Q21438939'], 'Dentagrilus': ['Q21219255', 'Q21438936']}
#
# Q132159 has children with same taxon names:  {'Catinella': ['Q3706132', 'Q53701944']}
#
# Q1064171 has children with same taxon names:  {'Borsoniinae': ['Q33140742', 'Q3721685'], 'Mitromorphinae': ['Q33142724', 'Q3716976']}
#
# Q2979376 has children with same taxon names:  {'Entobia': ['Q61593208', 'Q3055109']}
#
# Q3395514 has children with same taxon names:  {'Aplidiopsis': ['Q105003963', 'Q4926661']}
#
# Q5032117 has children with same taxon names:  {'Stenakrinae': ['Q61278283', 'Q21347751']}
#
# Q696598 has children with same taxon names:  {'Hermodice': ['Q3917355', 'Q104392325']}
#
# Q146602 has children with same taxon names:  {'Tochuina': ['Q104394536', 'Q7812016']}
#
# Q3464611 has children with same taxon names:  {'Cladocroce': ['Q4115180', 'Q105025116']}
#
# Q3274781 has children with same taxon names:  {'Dasystenella': ['Q21368794', 'Q104916503']}
#
# Q2076886 has children with same taxon names:  {'Peltaster': ['Q3460539', 'Q104993381']}
#
# Q2567254 has children with same taxon names:  {'Dinotrichales': ['Q5807486', 'Q18707570']}
#
# Q745912 has children with same taxon names:  {'Tribonematales': ['Q18674113', 'Q23070069']}
#
# Q2253036 has children with same taxon names:  {'Coprinopsis picacea': ['Q779716', 'Q105051440'], 'Coprinopsis macrocephala': ['Q10516474', 'Q105051436'], 'Coprinopsis cinerea': ['Q105051430', 'Q5168926'], 'Coprinopsis stercorea': ['Q10459226', 'Q105051499'], 'Coprinopsis nivea': ['Q105051437', 'Q28492325'], 'Coprinopsis stangliana': ['Q105051500', 'Q10459225'], 'Coprinopsis radiata': ['Q105051441', 'Q10477885']}
#
# Q248530 has children with same taxon names:  {'Lithistida': ['Q19327443', 'Q1968304']}
#
# Q19514242 has children with same taxon names:  {'Buprestina': ['Q19514298', 'Q4998033']}
#
# Q1953097 has children with same taxon names:  {'Myllaenini': ['Q30147070', 'Q64029195']}
#
# Q843136 has children with same taxon names:  {'Penicillium brevicompactum': ['Q7162860', 'Q105060238']}
#
# Q1377693 has children with same taxon names:  {'Acalypha wilkesiana ‘Hoffmanii’': ['Q9575825', 'Q9575766']}
#
# Q9577378 has children with same taxon names:  {'Acer ×freemanii ‘Autumn Fantasy’': ['Q18471098', 'Q18470613']}
#
# Q3022122 has children with same taxon names:  {'Geodia canaliculata': ['Q19943299', 'Q97012483'], 'Geodia mesotriaena': ['Q1993345', 'Q84218811'], 'Geodia nigra': ['Q86345508', 'Q2804203'], 'Geodia robusta': ['Q97728734', 'Q2387767']}
#
# Q25587 has children with same taxon names:  {'Hydrurga': ['Q16975912', 'Q105027751']}
# Q306495 has children with same taxon names:  {'Cortinarius paleaceus': ['Q11887243', 'Q105052002'], 'Cortinarius cinnamomeus': ['Q1084167', 'Q105051865'], 'Cortinarius albidus': ['Q2998110', 'Q105051811'], 'Cortinarius croceus': ['Q4347259', 'Q105051871'], 'Cortinarius evernius': ['Q5481564', 'Q105051884'], 'Cortinarius corrosus': ['Q10437677', 'Q105051870'], 'Cortinarius jenolanensis': ['Q24916020', 'Q105051963'], 'Cortinarius sclerophyllarum': ['Q49620024', 'Q105052031'], 'Cortinarius alboviolaceus': ['Q105051812', 'Q3915839'], 'Cortinarius austroalbidus': ['Q105051824', 'Q10460044'], 'Cortinarius glaucopus': ['Q105051956', 'Q3694823'], 'Cortinarius piriformis': ['Q105052010', 'Q10460182'], 'Cortinarius venetus': ['Q105052115', 'Q10609165'], 'Cortinarius rotundisporus': ['Q5173326', 'Q105052019'], 'Cortinarius sanguineus': ['Q9387379', 'Q105052026'], 'Cortinarius largus': ['Q10570865', 'Q105051969'], 'Cortinarius fragilipes': ['Q63140788', 'Q105051887'], 'Cortinarius argyrionus': ['Q105051818', 'Q5173310'], 'Cortinarius australis': ['Q105051822', 'Q49625778'], 'Cortinarius cinnabarinus': ['Q105051866', 'Q1081254'], 'Cortinarius memoria-annae': ['Q105051986', 'Q49625791'], 'Cortinarius subarcheri': ['Q105052038', 'Q10460213'], 'Cortinarius clelandii': ['Q4036562', 'Q105051867'], 'Cortinarius uliginosus': ['Q11838334', 'Q105052111'], 'Cortinarius cunninghamii': ['Q10460074', 'Q105051872'], 'Cortinarius globuliformis': ['Q10460107', 'Q105051958'], 'Cortinarius leucocephalus': ['Q10460135', 'Q105051976'], 'Cortinarius mariae': ['Q10460142', 'Q105051985'], 'Cortinarius persicanus': ['Q10460173', 'Q105052005'], 'Cortinarius austroviolaceus': ['Q101476894', 'Q105051836'], 'Cortinarius austrovenetus': ['Q105051835', 'Q2998123'], 'Cortinarius basorapulus': ['Q105051840', 'Q5173313'], 'Cortinarius microarcheri': ['Q105051988', 'Q24977281'], 'Cortinarius walkeri': ['Q105052123', 'Q49618584'], 'Cortinarius subcinnamomeus': ['Q63088430', 'Q105052039'], 'Cortinarius austrocyanites': ['Q105051826', 'Q10460047'], 'Cortinarius cinereoroseolus': ['Q105051864', 'Q5173314'], 'Cortinarius eartoxicus': ['Q105051876', 'Q24882907'], 'Cortinarius erythraeus': ['Q105051881', 'Q4036565'], 'Cortinarius metallicus': ['Q105051987', 'Q24977268'], 'Cortinarius saniosus': ['Q105052028', 'Q10510729'], 'Cortinarius nebulobrunneus': ['Q5173324', 'Q105051989'], 'Cortinarius elacatipus': ['Q10460087', 'Q105051877'], 'Cortinarius luteirufescens': ['Q105051979', 'Q10460138'], 'Cortinarius obtusus': ['Q105051995', 'Q10540297'], 'Cortinarius porphyroideus': ['Q105052011', 'Q5173325'], 'Cortinarius kioloensis': ['Q24191332', 'Q105051965'], 'Cortinarius controversus': ['Q105051869', 'Q26816843'], 'Cortinarius maculobulga': ['Q105051980', 'Q5173321'], 'Cortinarius bellus': ['Q10460050', 'Q105051841']}
#
# Q2707211 has children with same taxon names:  {'Omphalina scyphiformis': ['Q105059909', 'Q105059908'], 'Omphalina umbellifera': ['Q105059911', 'Q105059912'], 'Omphalina umbrinocarnosa': ['Q105059914', 'Q105059915']}
#
# Q622043 has children with same taxon names:  {'Hygrophorus cossus': ['Q105056410', 'Q10480811'], 'Hygrophorus flammans': ['Q105056413', 'Q105056412'], 'Hygrophorus discoideus': ['Q12671817', 'Q105056411'], 'Hygrophorus berkeleyi': ['Q62533962', 'Q62565837'], 'Hygrophorus prasinus': ['Q62554401', 'Q62533326'], 'Hygrophorus niveus': ['Q62532502', 'Q105056423']}
#
# Q520530 has children with same taxon names:  {'Hygrocybe virginea': ['Q112037', 'Q105056391'], 'Hygrocybe pseudograminicolor': ['Q49602950', 'Q105056312'], 'Hygrocybe apricosa': ['Q105056264', 'Q59461394'], 'Hygrocybe arcohastata': ['Q105056265', 'Q105056266'], 'Hygrocybe cantharellus': ['Q105056273', 'Q3915439'], 'Hygrocybe pallida': ['Q105056308', 'Q105056307'], 'Hygrocybe psittacina': ['Q105056313', 'Q177209'], 'Hygrocybe vallomarginata': ['Q105056387', 'Q105056386'], 'Hygrocybe wilsonensis': ['Q105056394', 'Q105056395'], 'Hygrocybe hypospoda': ['Q105056292', 'Q105056293'], 'Hygrocybe saltorivula': ['Q105056319', 'Q105056318'], 'Hygrocybe sciophana': ['Q105056323', 'Q105056322']}
#
# Q1338220 has children with same taxon names:  {'Suillus lacunosus': ['Q41735125', 'Q105067630'], 'Suillus flavus': ['Q105067624', 'Q96897486'], 'Suillus grevillei': ['Q105067627', 'Q833108'], 'Suillus granulatus': ['Q105067626', 'Q1142857'], 'Suillus brevipes': ['Q105067619', 'Q2712548']}
#
# Q5882693 has children with same taxon names:  {'Gonyaulax': ['Q5582128', 'Q104246542']}
#
# Q573152 has children with same taxon names:  {'Leccinum quercinum': ['Q105057391', 'Q4169309'], 'Leccinum scabrum': ['Q628977', 'Q105057393']}
#
# Q2717643 has children with same taxon names:  {'Bursaphis': ['Q27555873', 'Q50751148'], 'Pseudoprotaphis': ['Q50751153', 'Q51777991']}
#
# ...
#
# Q29908771 has children with same taxon names:  {'Collaria elegans': ['Q27996327', 'Q105051114']}
#
# Q23198196 has children with same taxon names:  {'Nodophilomedoidea': ['Q33189398', 'Q23045891']}
#
# Q275594 has children with same taxon names:  {'Bdelloidea': ['Q50703114', 'Q430301']}
#
# Q16527128 has children with same taxon names:  {'Alboleptonia sericella': ['Q54371195', 'Q105049027']}
#
# Q3446355 has children with same taxon names:  {'Rozites metallicus': ['Q59491520', 'Q105066531'], 'Rozites australiensis': ['Q105066528', 'Q59487661'], 'Rozites fusipes': ['Q63140783', 'Q105066530']}
#
# Q7179672 has children with same taxon names:  {'Pezoloma ericae': ['Q105060642', 'Q10625522']}
#
# Q10592874 has children with same taxon names:  {'Mystrosporium pulchrum': ['Q105059493', 'Q105059492']}
#
# Q18558643 has children with same taxon names:  {'Sclerodistominae': ['Q61484420', 'Q60329208']}
#
# Q5432789 has children with same taxon names:  {'Falsimohnia anderssoni': ['Q61685616', 'Q4881799']}
#
# Q724130 has children with same taxon names:  {'Plasmodiophora brassicae': ['Q1378682', 'Q105064946']}
#
# Q62503223 has children with same taxon names:  {'Pluteolus coprophilus': ['Q62503682', 'Q105065112']}
#
# Q7181041 has children with same taxon names:  {'Phasmomantis grandis': ['Q63968156', 'Q63969830']}
#
# Q150591 has children with same taxon names:  {'Silene undulata subsp. polyantha': ['Q64453825', 'Q66091661']}
#
# Q15557903 has children with same taxon names:  {'Schoenoplectiella purshiana var. williamsii': ['Q92436291', 'Q92436343']}
#
# Q67292955 has children with same taxon names:  {'Reichardia decapetala': ['Q67234988', 'Q67237061']}
#
# Q1815148 has children with same taxon names:  {'Disciotis venosa': ['Q105053262', 'Q1553596']}
#
# Q7255309 has children with same taxon names:  {'Pseudoplectania nigrella': ['Q105066189', 'Q1114526']}
#
# Q10606716 has children with same taxon names:  {'Octavianina flava': ['Q105059758', 'Q105059757']}
#
# Q14754830 has children with same taxon names:  {'Zygaena formosa formosa': ['Q83818849', 'Q21377866'], 'Zygaena formosa kotzschi': ['Q83818852', 'Q21377867']}
#
# Q8075768 has children with same taxon names:  {'Zygaena marcuna tlemceni': ['Q83904583', 'Q21377905'], 'Zygaena marcuna ahmarica': ['Q21377896', 'Q83904588'], 'Zygaena marcuna tingitana': ['Q83904577', 'Q21377904'], 'Zygaena marcuna numidia': ['Q83904593', 'Q21377903']}
#
# Q10576811 has children with same taxon names:  {'Micromphale foetidum': ['Q10680206', 'Q105058926']}
#
# Q156673 has children with same taxon names:  {'Papaya': ['Q86536341', 'Q17406004']}
#
# Q2790609 has children with same taxon names:  {'Serapias strictiflora var. elsae': ['Q92963359', 'Q92963406']}
#
# Q10865325 has children with same taxon names:  {'Rhynchospora corymbosa var. legrandii': ['Q93442665', 'Q93442643']}
#
# Q10863938 has children with same taxon names:  {'Wikstroemia dolichantha var. effusa': ['Q94450547', 'Q94450551']}
#
# Q7662019 has children with same taxon names:  {'Synaphea spinulosa subsp. borealis': ['Q94566220', 'Q94566188'], 'Synaphea spinulosa subsp. major': ['Q94566257', 'Q94566287']}
#
# Q87167558 has children with same taxon names:  {'Schlechterosciadium gracillimum': ['Q95507322', 'Q96002530']}
#
# Q20721665 has children with same taxon names:  {'Stemonitopsis typhina': ['Q56854775', 'Q105067329'], 'Stemonitopsis hyperopta': ['Q105067328', 'Q70868111']}
#
# Q2946333 has children with same taxon names:  {'Cephalotus': ['Q104247003', 'Q2181577']}
#
# Q935178 has children with same taxon names:  {'Pentadiplandra': ['Q104910646', 'Q15920057']}
#
# Q3344478 has children with same taxon names:  {'Notheia': ['Q104916289', 'Q21584337']}
#
# Q3516986 has children with same taxon names:  {'Darwinella': ['Q104916336', 'Q4118390']}
#
# Q2387255 has children with same taxon names:  {'Tridacna maxima': ['Q104923018', 'Q2704793']}
#
# Q61951663 has children with same taxon names:  {'Amplariella flavella': ['Q61951672', 'Q105049307']}
#
# Q10419139 has children with same taxon names:  {'Ascagilis bipolaris': ['Q105049505', 'Q10419138']}
#
# Q799011 has children with same taxon names:  {'Badhamia capsulifera': ['Q105049738', 'Q97061872'], 'Badhamia utricularis': ['Q799010', 'Q105049744'], 'Badhamia panicea': ['Q105049742', 'Q4840885']}
#
# Q55941585 has children with same taxon names:  {'Basidiophora entospora': ['Q105049779', 'Q55651549']}
#
# Q5004534 has children with same taxon names:  {'Byssoporia terrestris': ['Q105050113', 'Q10540871']}
#
# Q21708010 has children with same taxon names:  {'Byssus aurea': ['Q105050114', 'Q21872105']}
#
# Q5035977 has children with same taxon names:  {'Capitotricha bicolor': ['Q105050283', 'Q54366052']}
#
# Q10464751 has children with same taxon names:  {'Cyphellopsis anomala': ['Q105052501', 'Q10417809']}
#
# Q10469189 has children with same taxon names:  {'Dentipellis fragilis': ['Q105052905', 'Q10670216']}
#
# Q1210355 has children with same taxon names:  {'Dictydiaethalium plumbeum': ['Q105053047', 'Q49551729']}
#
# Q10519734 has children with same taxon names:  {'Helicomyces roseus': ['Q105055676', 'Q10519738']}
#
# Q10521113 has children with same taxon names:  {'Hemicorynespora mitrata': ['Q105055832', 'Q105055831']}
#
# Q1604807 has children with same taxon names:  {'Hemitrichia calyculata': ['Q14538457', 'Q105055837'], 'Hemitrichia clavata': ['Q105055839', 'Q14537693'], 'Hemitrichia serpula': ['Q105055841', 'Q1604808']}
#
# Q10529254 has children with same taxon names:  {'Hymeniopeltis major': ['Q105056447', 'Q105056446']}
#
# Q15643045 has children with same taxon names:  {'Kneiffiella setigera': ['Q105057162', 'Q105057163']}
#
# Q10570800 has children with same taxon names:  {'Lundquistia panici-leucophaei': ['Q105058141', 'Q105058140']}
#
# Q5227125 has children with same taxon names:  {'Macrocystidia cucumis': ['Q105058389', 'Q1555204']}
#
# Q10585015 has children with same taxon names:  {'Microxiphium pleomorphum': ['Q105059058', 'Q105059057']}
#
# Q10588687 has children with same taxon names:  {'Monotosporella sphaerica': ['Q105059157', 'Q105059158']}
#
# Q5225720 has children with same taxon names:  {'Phellorinia herculeana': ['Q105060816', 'Q10626923']}
#
# Q10648079 has children with same taxon names:  {'Queenslandia pulchella': ['Q105066315', 'Q10648080']}
#
# Q1615619 has children with same taxon names:  {'Tectella patellaris': ['Q105067706', 'Q7692811']}
#
# Q5518435 has children with same taxon names:  {'Galerella conocephala': ['Q10502089', 'Q105054553']}
#
# Q1611929 has children with same taxon names:  {'Montagnea arenaria': ['Q10588714', 'Q105059159']}
#
# Q2466809 has children with same taxon names:  {'Hydnum': ['Q159023', 'Q105186965']}
#
# Q7303195 has children with same taxon names:  {'Rectipilus fasciculatus': ['Q10650195', 'Q105066397'], 'Rectipilus sulphureus': ['Q105066398', 'Q10650198']}
#
# Q10429310 has children with same taxon names:  {'Biatoropsis usnearum': ['Q10670890', 'Q105049801']}
#
# Q10536460 has children with same taxon names:  {'Iodophanus carneus': ['Q10670958', 'Q105056922']}
#
# Q10675115 has children with same taxon names:  {'Sphaeronaemella fimicola': ['Q10675117', 'Q105067055']}
#
# Q10643245 has children with same taxon names:  {'Pseudoinonotus dryadeus': ['Q10708127', 'Q105066178']}
# Q15869897 has children with same taxon names:  {'Cerosterna scabrator': ['Q28432070', 'Q15858557']}
#
# Q177879 has children with same taxon names:  {'Cobitoidea': ['Q100143625', 'Q2246081']}
#
# Q21342261 has children with same taxon names:  {'Inaequifurcata': ['Q21342260', 'Q61668001'], 'Aequifurcata': ['Q21342264', 'Q61668002']}
#
# Q3042119 has children with same taxon names:  {'Pleraplysilla': ['Q3392278', 'Q104399348']}
#
# Q14529689 has children with same taxon names:  {'Zygaena haberhaueri haberhaueri': ['Q21377873', 'Q83970548'], 'Zygaena haberhaueri optima': ['Q83971435', 'Q21377875'], 'Zygaena haberhaueri demangei': ['Q21377871', 'Q83970563']}
#
# Q3197786 has children with same taxon names:  {'Acodontaster': ['Q3198001', 'Q104913171']}
#
# Q134869 has children with same taxon names:  {'Dicyemida': ['Q21447146', 'Q2224427']}
#
# Q25365857 has children with same taxon names:  {'Cyanoptyche gloeocystis': ['Q105444383', 'Q69523820']}
#
# Q19939 has children with same taxon names:  {'Panthera tigris sondaica': ['Q200381', 'Q55435725']}
#
# Q10584361 has children with same taxon names:  {'Microglossum olivaceum': ['Q10584362', 'Q105058922']}
#
# Q11845937 has children with same taxon names:  {'Neonymphon sp.': ['Q63708474', 'Q1905950']}
#
# Q1636732 has children with same taxon names:  {'Rivulicola incrustata': ['Q105066502', 'Q10655963']}
#
# Q1634023 has children with same taxon names:  {'Brandoniidae': ['Q60791498', 'Q33136434']}
#
# Q5526879 has children with same taxon names:  {'Gastropila fragilis': ['Q105054621', 'Q10503333']}
#
# Q9049646 has children with same taxon names:  {'Greenmaniella': ['Q5604322', 'Q104886681']}
#
# Q14667561 has children with same taxon names:  {'Tetrapleura andongensis': ['Q96357534', 'Q7706668']}
#
# Q2213564 has children with same taxon names:  {'Cheimonophyllum candidissimum': ['Q10549326', 'Q105050448']}
#
# Q5376390 has children with same taxon names:  {'Endoptychum melanosporum': ['Q10484001', 'Q105053543']}
#
# Q10494902 has children with same taxon names:  {'Fibroporia vaillantii': ['Q2720064', 'Q105053939']}
#
# Q1610174 has children with same taxon names:  {'Gymnogaster boletoides': ['Q10511459', 'Q105055088']}
#
# Q5227116 has children with same taxon names:  {'Lindtneria pellicularis': ['Q63213104', 'Q105058088']}
#
# Q10666783 has children with same taxon names:  {'Seuratia millardetii': ['Q105066862', 'Q10666786']}
#
# Q161745 has children with same taxon names:  {'Dianthus barbatus subsp. compactus': ['Q67175565', 'Q9275115']}
#
# Q5492775 has children with same taxon names:  {'Stylotrichium glomeratum': ['Q93392363', 'Q93392345']}
#
# Q1616126 has children with same taxon names:  {'Melanophyllum haematospermum': ['Q105058726', 'Q10508003']}
#
# Q8008411 has children with same taxon names:  {'Hispidocalyptella australis': ['Q10524572', 'Q105056011']}
#
# Q6546702 has children with same taxon names:  {'Lignincola laevis': ['Q10561534', 'Q105058074']}
#
# Q18713253 has children with same taxon names:  {'Cycloneritida': ['Q88577371', 'Q60477980']}
#
# Q2712508 has children with same taxon names:  {'Fayodia cystidiosa': ['Q59540232', 'Q105053933']}
#
# Q7189516 has children with same taxon names:  {'Physaria hemiphysaria var. lucens': ['Q93288430', 'Q93288452']}
#
# Q5647449 has children with same taxon names:  {'Handkea utriformis': ['Q54366505', 'Q105055564']}
#
# Q54430729 has children with same taxon names:  {'Pelitnus thorelli': ['Q54430695', 'Q54430671']}
#
# Q59420181 has children with same taxon names:  {'Struthiopteris spicant var. homophyllum': ['Q90153787', 'Q90608547']}
#
# Q87589685 has children with same taxon names:  {'Syringa patula var. venosa': ['Q93302618', 'Q93302635']}
#
# Q1306307 has children with same taxon names:  {'Paphiopedilum insigne f. sanderae': ['Q94337299', 'Q94337324'], 'Paphiopedilum insigne f. sanderianum': ['Q94337346', 'Q94337376']}
#
# Q15495000 has children with same taxon names:  {'Rodriguezia decora var. lactea': ['Q94554673', 'Q94554628']}
#
# Q87155065 has children with same taxon names:  {'Hypochoeris radicata': ['Q98915390', 'Q104403414']}
#
# Q18520783 has children with same taxon names:  {'Synute pulchellus': ['Q99373057', 'Q99373058', 'Q99373059']}
#
# Q20736138 has children with same taxon names:  {'Phaeodactylum': ['Q104387958', 'Q20675466']}
#
# Q3175417 has children with same taxon names:  {'Micromelo': ['Q104948164', 'Q6839664']}
#
# Q2300380 has children with same taxon names:  {'Cycloderma indicum': ['Q105052440', 'Q10464150']}
#
# Q11937773 has children with same taxon names:  {'Mucilago crustacea': ['Q105059177', 'Q1951637']}
#
# Q10597089 has children with same taxon names:  {'Neodasyscypha cerina': ['Q105059624', 'Q10510450']}
#
# Q292260 has children with same taxon names:  {'Phleogena faginea': ['Q105060850', 'Q10646553']}
#
# Q20721669 has children with same taxon names:  {'Symphytocarpus amaurochaetoides': ['Q105067640', 'Q70773318']}
#
# Q13514368 has children with same taxon names:  {'Caudata': ['Q53663', 'Q28208678']}
#
# Q10916972 has children with same taxon names:  {'Schisandra propinqua subsp. axillaris': ['Q94445767', 'Q94445787']}
#
# Q7166928 has children with same taxon names:  {'Peramus': ['Q41156804', 'Q85792791']}
#
# Q49604280 has children with same taxon names:  {'Microcera rectispora': ['Q105058921', 'Q105058918']}
#
# Q28345654 has children with same taxon names:  {'Metatrichia floriformis': ['Q105058915', 'Q70447125']}
#
# Q134854 has children with same taxon names:  {'Cypsiurus gracilis': ['Q65050840', 'Q81901546']}
#
# Q22943968 has children with same taxon names:  {'Nummoloculina irregularis': ['Q66227487', 'Q66228166']}
#
# Q3545396 has children with same taxon names:  {'Selaginella apoda subsp. eclipes': ['Q94445928', 'Q94445955']}
#
# Q87182415 has children with same taxon names:  {'Schedololium ×loliaceum': ['Q94398346', 'Q94398394']}
#
# Q15558567 has children with same taxon names:  {'Tephroseris hyperborealis subsp. wrangelica': ['Q94566818', 'Q94566781']}
#
# Q1141605 has children with same taxon names:  {'Galbulimima': ['Q104921466', 'Q146765']}
#
# Q131817 has children with same taxon names:  {'Aralidium': ['Q104992555', 'Q1364407']}
#
# Q61596376 has children with same taxon names:  {'Dictyolus australis': ['Q105053057', 'Q62395019']}
#
# Q5229588 has children with same taxon names:  {'Gasteroagaricoides ralstoniae': ['Q105054620', 'Q15643656']}
#
# Q10590312 has children with same taxon names:  {'Munkiella melastomata': ['Q105059196', 'Q105059197']}
#
# Q10431596 has children with same taxon names:  {'Blumeria graminis': ['Q337796', 'Q105049830']}
#
# Q42310233 has children with same taxon names:  {'Centrobolus': ['Q66768504', 'Q42310231']}
#
# Q15370743 has children with same taxon names:  {'Suessenguthia vargasii var. hirsuta': ['Q93317438', 'Q93317454']}
#
# Q5376229 has children with same taxon names:  {'Endocellion gmelinii': ['Q94514433', 'Q94514485']}
#
# Q3040036 has children with same taxon names:  {'Drosophyllum': ['Q104252519', 'Q13107254']}
#
# Q4804055 has children with same taxon names:  {'Ascotremella faginea': ['Q105049571', 'Q605828']}
#
# Q1610848 has children with same taxon names:  {'Barcheria willisiana': ['Q105049757', 'Q10426332']}
#
# Q10450983 has children with same taxon names:  {'Choreospora tibellii': ['Q105050490', 'Q10450984']}
#
# Q2749532 has children with same taxon names:  {'Eucommia': ['Q5406185', 'Q104253080']}
#
# Q5464929 has children with same taxon names:  {'Fomitella supina': ['Q5464935', 'Q105054377']}
#
# Q10462893 has children with same taxon names:  {'Ctenomyces serratus': ['Q10462894', 'Q105052329']}
#
# Q13518421 has children with same taxon names:  {'Lacertoidea': ['Q33188008', 'Q13518423']}
#
# Q87150263 has children with same taxon names:  {'Diplothrix acerosa': ['Q95936528', 'Q95936546']}
#
# Q13777503 has children with same taxon names:  {'Lanaria': ['Q104387698', 'Q15712353']}
#
# Q3950213 has children with same taxon names:  {'Subergorgia': ['Q104393145', 'Q3331685']}
#
# Q10505593 has children with same taxon names:  {'Globosphaeria jamesii': ['Q105054811', 'Q10505594']}
#
# Q1818826 has children with same taxon names:  {'Leocarpus fragilis': ['Q105057646', 'Q1575659']}
#
# Q10598203 has children with same taxon names:  {'Neophoma goodeniae': ['Q105059635', 'Q105059636']}
#
# Q62492779 has children with same taxon names:  {'Nyctalis mirabilis': ['Q105059736', 'Q62493102']}
#
# Q1027408 has children with same taxon names:  {'Calomyxa metallica': ['Q70774192', 'Q105050167']}
#
# Q1096177 has children with same taxon names:  {'Clastoderma debaryanum': ['Q70867122', 'Q105050624']}
#
# Q10428811 has children with same taxon names:  {'Bertrandia astatogala': ['Q10428810', 'Q105049800']}
#
# Q15100413 has children with same taxon names:  {'Climacocystis borealis': ['Q105050947', 'Q1891829']}

# %%
len(repetitive_taxon_names)
# Out:
# 1033

# %%
'''
for each parent, check if its children has different ranks
'''
different_rank_siblings = {}
for node_code, children_code in tree.items():
    try:
        children_ranks = {id_rank_dict[child] for child in children_code}
        if len(children_ranks) > 1:
            different_rank_siblings[node_code] = children_ranks                   
            print(node_code, "has children with different ranks: ", children_ranks)
    except:
        continue
# Out:
# Q602740 has children with different ranks:  {'Q767728', 'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'NA'}
# Q157396 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q157714 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q157337 has children with different ranks:  {'Q3181348', 'Q7432', 'Q68947', 'Q3238261'}
# Q157656 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q1100242 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1017395 has children with different ranks:  {'Q3025161', 'Q7432', 'Q3238261', 'Q3181348'}
# Q136934 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q2656869 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q156146 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q4886', 'Q3025161'}
# Q159220 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q131511 has children with different ranks:  {'Q164280', 'Q34740'}
# Q157381 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q608099 has children with different ranks:  {'Q3025161', 'Q7432', 'Q3238261', 'Q3181348'}
# Q129016 has children with different ranks:  {'Q3025161', 'Q7432', 'Q5998839', 'Q3181348'}
# Q17167613 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q157264 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q1802740 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q165315 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q934037 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q690633 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q296910 has children with different ranks:  {'Q3181348', 'Q7432', 'Q4886', 'Q3238261'}
# Q1424322 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q3025161'}
# Q10771886 has children with different ranks:  {'Q3025161', 'Q7432', 'Q3181348'}
# Q29128 has children with different ranks:  {'Q7432', 'Q4886'}
# Q2703736 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q189393 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q4886', 'Q3025161'}
# Q157634 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q4150646', 'Q5998839', 'Q7432', 'Q4886', 'Q3025161'}
# Q7237437 has children with different ranks:  {'Q3181348', 'Q5998839', 'Q7432', 'Q4886', 'Q3025161'}
# Q156764 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q309213 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q1856821 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q133714 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q161085 has children with different ranks:  {'Q3025161', 'Q7432', 'Q3238261'}
# Q5347305 has children with different ranks:  {'Q7432', 'Q3238261', 'Q4886', 'Q3181348'}
# Q133724 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
#
has children with different ranks:  {'Q7432', 'Q3181348'}
# Q160090 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q156047 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3181348', 'Q3238261'}
# Q4821680 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q4748169 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q543142 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3181348'}
# Q386328 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q157069 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q3025161'}
# Q156421 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q160835 has children with different ranks:  {'Q164280', 'Q34740'}
# Q18653997 has children with different ranks:  {'Q227936', 'Q34740'}
# Q157184 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3025161', 'Q3181348'}
# Q3303714 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q21139 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q904250 has children with different ranks:  {'Q3025161', 'Q7432', 'Q3238261', 'Q3181348'}
# Q133754 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1713273 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q156354 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q146217 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q157544 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3238261', 'Q3181348'}
# Q2670159 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q163963 has children with different ranks:  {'Q767728', 'Q4886', 'Q68947'}
# Q160352 has children with different ranks:  {'Q767728', 'Q279749'}
# Q134091 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q159182 has children with different ranks:  {'Q767728', 'Q4886', 'Q68947'}
# Q2670152 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q3645698 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q161849 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q1974080 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3181348'}
# Q5197050 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q1989603 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q29979 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q3025161'}
# Q2671037 has children with different ranks:  {'Q68947', 'Q767728'}
# Q15289828 has children with different ranks:  {'Q68947', 'Q767728'}
# Q521478 has children with different ranks:  {'Q767728', 'Q68947'}
# Q5260817 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q165290 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q2719968 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q133768 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q160189 has children with different ranks:  {'Q630771', 'Q767728', 'Q279749', 'Q68947'}
# Q1625033 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q133797 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q5374388 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q9599028 has children with different ranks:  {'Q767728', 'Q279749'}
# Q5420696 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1318743 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q9598268 has children with different ranks:  {'Q767728', 'Q279749'}
# Q2356320 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q163509 has children with different ranks:  {'Q767728', 'Q68947'}
# Q7396081 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q159407 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q162001 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q2333118 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3181348'}
# Q133786 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q159180 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q134242 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q2886775 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q148633 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3025161', 'Q3181348'}
# Q132636 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q311044 has children with different ranks:  {'Q767728', 'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q3025161'}
# Q311881 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q843914 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q10373662 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q133773 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q1306176'}
# Q163541 has children with different ranks:  {'Q1306176', 'Q7432'}
# Q133778 has children with different ranks:  {'Q5998839', 'Q7432', 'Q4886', 'Q3181348'}
# Q2719974 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q2720003 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q1622040 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q15952699 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q740887 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q147105 has children with different ranks:  {'Q3181348', 'Q3238261', 'Q5998839', 'Q7432', 'Q3025161'}
# Q7685791 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q9597036 has children with different ranks:  {'Q68947', 'Q279749', 'Q767728'}
# Q2716557 has children with different ranks:  {'Q5998839', 'Q7432', 'Q3181348'}
# Q1391873 has children with different ranks:  {'Q767728', 'Q279749', 'Q4886', 'Q68947'}
# Q2703896 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q15288563 has children with different ranks:  {'Q68947', 'Q279749', 'Q767728'}
# Q157270 has children with different ranks:  {'Q7432', 'Q4886', 'Q3238261'}
# Q165260 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q162477 has children with different ranks:  {'Q630771', 'Q767728', 'Q68947'}
# Q287313 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1066183 has children with different ranks:  {'Q164280', 'Q34740'}
# Q149875 has children with different ranks:  {'Q227936', 'NA', 'Q34740'}
# Q15288457 has children with different ranks:  {'Q68947', 'Q767728'}
# Q2245139 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1948936 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q15288470 has children with different ranks:  {'Q767728', 'Q279749', 'Q68947'}
# Q15288405 has children with different ranks:  {'Q767728', 'Q68947'}
# Q3906027 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q1309069 has children with different ranks:  {'Q3181348', 'Q7432', 'Q3238261'}
# Q9005036 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q2720025 has children with different ranks:  {'Q7432', 'Q3238261', 'Q3181348'}
# Q1601232 has children with different ranks:  {'Q7432', 'Q3181348'}
# Q9572799 has children with different ranks:  {'Q630771', 'Q767728'}
# Q18108617 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q1367607 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q8008955 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q2286111 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q7321575 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q1305617 has children with different ranks:  {'Q7432', 'Q3238261'}
# Q5272410 has children with different ranks:  {'Q7432', 'Q3238261'}
#
# Q10749227 has children with different ranks:  {'Q767728', 'Q279749'}
# Q1076243 has children with different ranks:  {'Q767728', 'Q279749'}
# Q152553 has children with different ranks:  {'Q68947', 'Q767728'}
# Q1937703 has children with different ranks:  {'Q767728', 'Q279749'}
# Q12230809 has children with different ranks:  {'Q68947', 'Q767728'}
# Q12210847 has children with different ranks:  {'Q767728', 'Q279749'}
# Q15227383 has children with different ranks:  {'Q68947', 'Q279749'}
# Q147700 has children with different ranks:  {'Q68947', 'Q767728'}
# Q89158140 has children with different ranks:  {'Q767728', 'Q279749'}
# Q1149768 has children with different ranks:  {'Q767728', 'Q279749'}
# Q17731744 has children with different ranks:  {'Q767728', 'Q68947'}
# Q15583792 has children with different ranks:  {'Q68947', 'Q767728'}
# Q8222480 has children with different ranks:  {'Q35409', 'Q34740'}
# Q4591380 has children with different ranks:  {'Q2889003', 'NA'}
# Q21447000 has children with different ranks:  {'Q37517', 'Q3504061'}
# Q9021682 has children with different ranks:  {'Q164280', 'Q34740'}
# Q4173968 has children with different ranks:  {'Q36602', 'Q34740'}
# Q190115 has children with different ranks:  {'Q37517', 'Q36602'}
# Q2270217 has children with different ranks:  {'NA', 'Q34740'}

# %%
len(different_rank_siblings)
# Out:
# 18716

# %%
'''
There are also entries with no parent information therefore they are not present in any trees
'''
data[data["parent_taxon"].isna()]
# Out:
#                 id                 taxon_name taxon_rank parent_taxon  \
# 31362        P1070                        NaN        NaN          NaN
# 37931        P1137                        NaN        NaN          NaN
# 68300        P1772                        NaN        NaN          NaN
# 70202    Q20672521                        NaN        NaN          NaN
# 87883    Q21398146                        NaN        NaN          NaN
# ...            ...                        ...        ...          ...
# 2790422       P960                        NaN        NaN          NaN
# 2794225    Q667161  Tetrao tetrix × urogallus        NaN          NaN
# 2821400   Q2382443                      Biota  Q22666877          NaN
# 2848888   Q2005736                        NaN        NaN          NaN
# 2854067       P105                        NaN        NaN          NaN
#
#                                   species_name_value
# 31362                                   PlantList-ID
# 37931                      fossil found in this unit
# 68300                                 USDA PLANTS ID
# 70202                               Serpentine rouge
# 87883    Puccinia asteris ß chrysanthemi-leucanthemi
# ...                                              ...
# 2790422                                  Tropicos ID
# 2794225                                   Rackelhahn
# 2821400                                        biota
# 2848888                               SIG Sauer P225
# 2854067                                   taxon rank
#
# [1149 rows x 5 columns]

# %%
'''
There are two Biota, but the second one is the root
'''
data[data["taxon_name"] == "Biota"]
# Out:
#                 id taxon_name taxon_rank parent_taxon species_name_value
# 1669271  Q87177320      Biota     Q34740      Q146037              Biota
# 2821400   Q2382443      Biota  Q22666877          NaN              biota

# %%
# build the tree of life with Biota as root
tree_from_biota = build_tree_from_root("Q2382443", tree, id_name_dict, id_rank_dict)
with open('tree.json', 'w') as fp:
    json.dump(tree_from_biota, fp)

# %%
# build the "dangling trees" for roots that are not Biota
for missing_parent in missing_parents:
    dangling_tree = build_tree_from_root(missing_parent, tree, id_name_dict, id_rank_dict)
    file_name = os.path.join(WIKIDIR, "dangling_trees",missing_parent + ".json")
    with open(file_name, 'w') as fp:
        json.dump(dangling_tree, fp, indent=4)
